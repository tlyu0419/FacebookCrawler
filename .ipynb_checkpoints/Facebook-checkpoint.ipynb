# %% [markdown]
# # Facebook爬蟲
# 這裡簡單介紹一下爬蟲的邏輯再開始爬進入正題吧！
# - 爬取文章內容
#  - 貼文人ID
#  - 貼文人暱稱
#  - 貼文時間
#  - 貼文類型
#  - 貼文內容
#  - 心情：分為Like, Haha, Sad, Wow, Angry...etc.
#  - 留言數
#  - 分享數
#  - 貼文連結
#
#
# - 爬取留言內容
#  - 留言人ID
#  - 留言人暱稱
#  - 留言時間
#  - 回覆對象ID
#  - 回覆對象暱稱
#  - 貼文連結

# %% [markdown]
# # 載入使用套件

# %%
import pandas as pd
import re, time, requests, datetime, gc
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# # 截取塗鴉墻貼文資訊並比對先前資料
# 如果每次都把所有貼文抓下來，無疑會浪費程式效能，在這裡我將載入先前的資料，並將各篇貼文分成以下三類：
#
# - **新貼文**：截取貼文內容與留言
# - **舊貼文但有新留言**：截取所有留言但只將新留言加入資料庫
# - **舊貼文也無新留言**：不處理
#
# 可想而知，如果設定排程每天執行，大多數資料都會是「舊貼文也無新留言」的類型，加入這個判斷機制將大幅節省系統效能

# %%
# 點擊不要現在註冊帳號
def clickNotNow():
    try:
        driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    except:
        time.sleep(0.5)

# 截取塗鴉墻上貼文的留言數
def GetWall_PostCommentCounts(i):
    try:
        CommentCounts = i.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0
    return CommentCounts

# 截取塗鴉墻上貼文的連結
def GetWall_PostLink(i):
    Link = 'https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0]
    return Link

# 截取塗鴉墻上貼文的發佈時間
def GetWall_PostTime(i):
    try:
        Time = i.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = 'Not Post'
    return Time

def CarwlList(urls, n, Posts):
    CheckList = pd.DataFrame(columns = ['Link','Time','CommentCounts']) 
    for i in urls:
        driver.get(i)        
        for i in range(n):
            try:
                time.sleep(1)
                driver.find_element_by_css_selector('a.pam.uiBoxLightblue.uiMorePagerPrimary').click() # 加載更多貼文的按鈕
            except:
                time.sleep(1)
            # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
            clickNotNow()
            soup = BeautifulSoup(driver.page_source)
            for i in soup.find_all('div', {'class':'_5pcr userContentWrapper'}):
                CheckList = pd.concat([CheckList, pd.DataFrame(data = [{'Link':GetWall_PostLink(i),
                                                                        'Time':GetWall_PostTime(i),
                                                                        'CommentCounts':GetWall_PostCommentCounts(i)}],
                                                               columns = ['Link','Time','CommentCounts'])],
                                       ignore_index = True)
    
    CarwlList = pd.merge(left = CheckList,
                         right = Posts.loc[:,['Link','CommentCounts']],
                         how='left',
                         on='Link',
                         suffixes=('_c', '_p'),
                         indicator=True)
    CarwlList = pd.concat([CarwlList.loc[CarwlList._merge == 'left_only', :], # 新貼文
                           CarwlList.loc[CarwlList.CommentCounts_c > CarwlList.CommentCounts_p, :]], # 舊貼文但有新留言
                          ignore_index=True)
    CarwlList = CarwlList.drop_duplicates(subset = 'Link',
                                          keep= 'first',
                                          inplace = False)
    return CarwlList

# %% [markdown]
# # 爬取特定貼文的內容與留言
# ## 展開貼文與留言

# %%
# 選擇按照New或Oldest來顯示留言(選擇最相關或所有留言都不會會真的顯示所有留言)
def clickOldest():
    driver.find_element_by_xpath('//a[@data-testid="UFI2ViewOptionsSelector/link"]').click()
    time.sleep(1)
    try:
        driver.find_element_by_partial_link_text('Comments shown in chronological order with the oldest comments at the top.').click()
    except:
        try:
            driver.find_element_by_partial_link_text('New comments and those with new replies appear at the top.').click()
        except:
            print('Plz, Check this post arragne type!')

# 打開各篇貼文並展開所有留言 與 留言的留言
def PostExpand():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
    clickNotNow()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
    clickNotNow()
    time.sleep(0.5)
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()    
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    clickNotNow()
    time.sleep(0.5)
    clickOldest()
    time.sleep(1)
    clickNotNow()
    
    # 偵測是否有「更多留言」（第一層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(1)
            except:
                time.sleep(0.5)   
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(1)
            except:
                time.sleep(0.5)
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)

# %% [markdown]
# ## 爬取貼文內容與留言資訊

# %%
# 貼文留言數
def Post_Name(userContent):
    return userContent.find('img').attrs['aria-label']

# 貼文留言數
def Post_ID(userContent):
    return userContent.find('a', {'class':'_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe'}).attrs['href'].split('/?ref')[0].split('https://www.facebook.com/')[1]

# 貼文時間
def Post_Time(userContent):
    try:
        Time = userContent.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = "Error, Please check this post's condiction!" 
    return Time

# 貼文內容
def Post_Content(userContent):
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = "There's No Text Content!"
    return Content

# 貼文留言數
def Post_Comments(userContent):
    try:
        CommentCounts = userContent.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0 
    return CommentCounts

# 貼文分享數
def Post_Shares(userContent):
    try:
        ShareCounts = userContent.find('span', {'class':'_355t _4vn2'}).text.split(' ',2)[0]
        if 'K' in ShareCounts:
            ShareCounts = int(float(ShareCounts.split('K')[0])*1000)
        else:
            ShareCounts = int(ShareCounts)
    except:
        ShareCounts = 0
    return ShareCounts

# 貼文按讚心情數
def Post_Likes(userContent):
    try:
        LikeCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LikeCounts:
            LikeCounts = int(float(LikeCounts.split('K')[0])*1000)
        else:
            LikeCounts = int(LikeCounts)
    except:
        LikeCounts = 0
    return LikeCounts

# 貼文愛心心情數
def Post_Loves(userContent):
    try:
        LoveCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LOVE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LoveCounts:
            LoveCounts = int(float(LoveCounts.split('K')[0])*1000)
        else:
            LoveCounts = int(LoveCounts)
    except:
        LoveCounts = 0
    return LoveCounts

# 貼文哈哈心情數
def Post_Hahas(userContent):
    try:
        HahaCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in HahaCounts:
            HahaCounts = int(float(HahaCounts.split('K')[0])*1000)
        else:
            HahaCounts = int(HahaCounts)
    except:
        HahaCounts = 0
    return HahaCounts

# 貼文Wow心情數
def Post_Wows(userContent):
    try:
        WowCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_WOW'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in WowCounts:
            WowCounts = int(float(WowCounts.split('K')[0])*1000)
        else:
            WowCounts = int(WowCounts)
    except:
        WowCounts = 0
    return WowCounts

# 貼文Sad心情數
def Post_Sads(userContent):
    try:
        SadCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_SORRY'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in SadCounts:
            SadCounts = int(float(SadCounts.split('K')[0])*1000)
        else:
            SadCounts = int(SadCounts)
    except:
        SadCounts = 0
    return SadCounts

# 貼文Angry心情數
def Post_Angrys(userContent):
    try:
        AngryCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in AngryCounts:
            AngryCounts = int(float(AngryCounts.split('K')[0])*1000)
        else:
            AngryCounts = int(AngryCounts)
    except:
        AngryCounts = 0
    return AngryCounts

# 文章內容與互動摘要
def PostInfo(soup):
    # 貼文區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    PostContent = pd.DataFrame(data = [{'Name':Post_Name(userContent),
                                        'ID':Post_ID(userContent),
                                        'Time':Post_Time(userContent),
                                        'Content':Post_Content(userContent),
                                        'Comments':Post_Comments(userContent),
                                        'Shares':Post_Shares(userContent),
                                        'Likes':Post_Likes(userContent),
                                        'Loves':Post_Loves(userContent),
                                        'Hahas':Post_Hahas(userContent),
                                        'Wows':Post_Wows(userContent),
                                        'Sads':Post_Sads(userContent),
                                        'Angrys':Post_Angrys(userContent),
                                        'Updatetime':datetime.datetime.now().strftime("%Y-%m-%d %H:%M"),
                                        'Link':driver.current_url}],
                            columns = ['Name', 'ID', 'Time', 'Content', 'Comments', 'Shares', 'Likes', 'Loves', 'Hahas', 'Wows', 'Sads', 'Angrys', 'Updatetime', 'Link'])
    return PostContent

# 留言內容
def Comment_Content(element):
    try:
        Content = element.find('span', {'dir':'ltr'}).text
    except:
        Content = 'img'
    return Content

def CommentsInfo(soup):  
    PostComments = pd.DataFrame()
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    try:
        for i in userContent.select('ul._7a9a > li'):
            # 先抓留言並放在Comment
            Comment = pd.DataFrame(data=[{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                          'Name':i.find('img').attrs['alt'],
                                          'Time':datetime.datetime.strptime(i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                          'Content':Comment_Content(i),
                                          'RepID':userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1],
                                          'RepName':userContent.find('img').attrs['aria-label'],
                                          'Link':driver.current_url}],
                                   columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
            PostComments = pd.concat([PostComments, Comment], ignore_index=True)
            # 留言的留言
            for j in i.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
                Comment = pd.DataFrame(data=[{'ID':j.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'Name':j.find('img').attrs['alt'],
                                              'Time':datetime.datetime.strptime(j.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                              'Content':Comment_Content(j),
                                              'RepID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'RepName':i.find('img').attrs['alt'],
                                              'Link':driver.current_url}],
                                       columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
                PostComments = pd.concat([PostComments, Comment], ignore_index=True)
        PostComments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
    except:
        print('Crawl Comments Failed!')
    return PostComments

# %% [markdown]
# # 更新貼文與留言資訊
# 將最新抓到的貼文併回Post表格，並以ID與Time作為關鍵(key)值，取最新抓取的資料(Updatetime)

# %%
def UpdateData(DateFrame_o,DateFrame_n):
    DataFrame = pd.concat([DateFrame_o, DateFrame_n], ignore_index=True)
    DataFrame = DataFrame.sort_values(by = 'Updatetime', ascending = False)
    DataFrame = DataFrame.drop_duplicates(subset = ['ID', 'Time', 'Content'],
                                          keep= 'first',
                                          inplace = False)
    return DataFrame

# %% [markdown]
# # 爬資料
# ## 讀取先前資料
# 若在桌面偵測不到檔案，就創造新的dataframe

# %%
try:
    Posts = pd.read_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'Comments', 'Shares', 'Likes', 'Loves', 'Hahas', 'Wows', 'Sads', 'Angrys', 'Updatetime', 'Link'])
try:
    Comments = pd.read_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link', 'Updatetime'])
    
urls = ['https://www.facebook.com/tstartel/',
        'https://www.facebook.com/chtmobile/',
        'https://www.facebook.com/taiwanmobile/',
        'https://www.facebook.com/fareastone/',
        'https://www.facebook.com/Aptg.tw/']

# %% [markdown]
# ## 產出待爬清單

# %%
driver = webdriver.Chrome()
driver.get('https://www.facebook.com/')
time.sleep(1)
driver.find_element_by_partial_link_text('English').click()

# %%
CarwlList = CarwlList(urls=urls, n=10, Posts = Posts)
CarwlList
# Out:
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                    Link              Time  \
# 0     https://www.facebook.com/tstartel/posts/328473...  2019-05-19 20:52
# 7     https://www.facebook.com/tstartel/posts/318846...  2019-04-11 04:48
# 12    https://www.facebook.com/tstartel/videos/58966...  2019-03-31 21:03
# 13    https://www.facebook.com/chtmobile/photos/a.26...  2019-05-21 02:00
# 14    https://www.facebook.com/chtmobile/posts/27207...  2019-05-20 02:00
# 15    https://www.facebook.com/chtmobile/photos/a.26...  2019-05-17 02:00
# 19    https://www.facebook.com/chtmobile/photos/a.26...  2019-05-14 02:42
# 20    https://www.facebook.com/chtmobile/posts/27033...  2019-05-08 02:00
# 21    https://www.facebook.com/chtmobile/videos/6635...  2019-04-29 03:18
# 28    https://www.facebook.com/chtmobile/photos/a.26...  2019-04-19 02:00
# 29    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-04-18 22:49
# 30    https://www.facebook.com/chtmobile/posts/26562...  2019-04-17 00:37
# 40    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-04-08 20:36
# 51    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-04-02 00:35
# 52    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-29 02:00
# 53    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-28 02:00
# 54    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-03-28 01:59
# 55    https://www.facebook.com/chtmobile/posts/26214...  2019-03-27 21:00
# 56    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-27 02:00
# 73    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-20 03:08
# 74    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-14 02:00
# 75    https://www.facebook.com/chtmobile/photos/a.26...  2019-03-07 01:00
# 95    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-02-27 02:12
# 96    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-02-23 04:14
# 97    https://www.facebook.com/chtmobile/photos/a.26...  2019-02-22 01:14
# 98    https://www.facebook.com/chtmobile/videos/5589...  2019-02-19 22:17
# 99    https://www.facebook.com/notes/%E4%B8%AD%E8%8F...  2019-02-18 00:28
# 148   https://www.facebook.com/chtmobile/photos/a.26...  2019-02-15 20:00
# 149   https://www.facebook.com/chtmobile/photos/a.26...  2019-02-14 01:00
# 150   https://www.facebook.com/chtmobile/photos/a.26...  2019-02-13 01:00
# ...                                                 ...               ...
# 962   https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-02 20:00
# 963   https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-01 20:00
# 964   https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-02 00:00
# 966   https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-04
# 1064             782              NaN  left_only
# 1065               2              NaN  left_only
# 1066               6              NaN  left_only
# 1067               2              NaN  left_only
# 1068               8              NaN  left_only
# 1069             993              NaN  left_only
# 1070               4              NaN  left_only
# 1130              24              NaN  left_only
# 1131               3              NaN  left_only
# 1132               1              NaN  left_only
# 1133              15              NaN  left_only
# 1134              19              NaN  left_only
# 1135              43              NaN  left_only
# 1136            1500              NaN  left_only
# 1137               3              NaN  left_only
#
# [250 rows x 5 columns]

# %% [markdown]
# 如同上面的說明，當CheckLists「merge」欄位為「left_only」時表示該貼文是新貼文；
#
# 而當「merge」欄位為「both」，但「Comments_c」的值大於「Comments_p」時，表示該貼文是舊資料但有新留言。
#
# 以下將截取這兩類的貼文作為爬取清單

# %% [markdown]
# ## 執行爬蟲

# %%
for i in CarwlList.Link:
    print('Dealing with: ' + i)
    driver.get(i)
    try:
        PostExpand()
        time.sleep(2)
        print('Expand Succed!')
        try:
            soup = BeautifulSoup(driver.page_source)
            time.sleep(1)
            nPost = PostInfo(soup)
            Posts = UpdateData(DateFrame_o = Posts, DateFrame_n = nPost)
            print('Update PostInfo complete!')
            try:
                nComments = CommentsInfo(soup)
                Comments = UpdateData(DateFrame_o = Comments,DateFrame_n = nComments)
                print('Update CommentsInfo complete!')
            except:
                print('Update CommentsInfo Failed!')
        except:
            print('Crawl Post or Comments Failed!')
    except:
        print('Expand Failed!')
    gc.collect()
    print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '\n\n------------------')
# Out:
# Dealing with: https://www.facebook.com/tstartel/posts/3284730548219636
# Expand Failed!
# Time Log: 2019-05-27 12:47:44
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/3188462841179741
# Expand Failed!
# Time Log: 2019-05-27 12:47:52
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/589662731510587/
# Expand Failed!
# Time Log: 2019-05-27 12:47:57
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2722896354406656/
# Expand Failed!
# Time Log: 2019-05-27 12:48:06
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2720795567950068
# Expand Failed!
# Time Log: 2019-05-27 12:48:11
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2722488054447486/
# Expand Failed!
# Time Log: 2019-05-27 12:48:19
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2715269541836004/
# Expand Failed!
# Time Log: 2019-05-27 12:48:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2703335766362715
# Expand Failed!
# Time Log: 2019-05-27 12:48:33
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/663589520750150/
# Expand Failed!
# Time Log: 2019-05-27 12:48:42
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2673077649388527/
# Expand Failed!
# Time Log: 2019-05-27 12:48:49
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E5%BF%AB%E4%BE%86%E4%B8%80%E8%B5%B7%E4%BA%AB%E7%94%A8hami%E7%93%9C%E5%B8%B6%E4%BE%86%E5%A5%BD%E5%BA%B7%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2741451985881855/
# Expand Failed!
# Time Log: 2019-05-27 12:48:55
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2656205787742380
# Expand Succed!
# Update PostInfo complete!
# Update CommentsInfo complete!
# Time Log: 2019-05-27 12:49:15
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E6%B8%85%E6%98%8E%E9%80%A3%E5%81%87%E8%8F%AF%E7%B7%A8%E6%94%BE%E5%81%87%E7%A7%98%E7%AC%88%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2725299120830475/
# Expand Failed!
# Time Log: 2019-05-27 12:49:21
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/hami-%E8%80%81%E5%B8%AB%E7%9A%84%E6%9C%89%E7%8D%8E%E5%BE%B5%E7%AD%94%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2714190525274668/
# Expand Failed!
# Time Log: 2019-05-27 12:49:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2635660743130218/
# Expand Succed!
# Update PostInfo complete!
# Update CommentsInfo complete!
# Time Log: 2019-05-27 12:49:42
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2625898320773127/
# Expand Failed!
# Time Log: 2019-05-27 12:49:47
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E6%A6%AE%E7%8D%B2%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9F%E4%B8%89%E5%86%A0%E7%8E%8B%E5%8F%B0%
Comments.to_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')

# %%
#Posts.to_csv('C:/Users/TL_Yu/Desktop/Posts.csv')
#Comments.to_csv('C:/Users/TL_Yu/Desktop/Comments.csv')

# %% [markdown]
# # 維護測試區

# %%
driver = webdriver.Chrome()
driver.get('https://www.facebook.com/')
time.sleep(1)
driver.find_element_by_partial_link_text('English').click()

# %%
# https://www.facebook.com/tstartel/posts/3284730548219636
# https://www.facebook.com/tstartel/videos/1100239263492734/?permPage=1
driver.get('https://www.facebook.com/tstartel/posts/3274403725918985')
ClosePopup()
ClickOldest()
MoreComments()
MoreReplies2()
# Out:
# Click More Comments times： 0
# Click More Comments times： 1
# Click More Comments times： 2
# Click More Comments times： 3
# Click More Comments times： 4
# Click More Comments times： 5
# Click More Comments times： 6
# Click More Comments times： 7
# Click More Comments times： 8
# Click More Comments times： 9
# Click More Comments times： 10
# Click More Comments times： 11
# Click More Comments times： 12
# Click More Replies times： 1
# Click More Replies times： 2
# Click More Replies times： 3
# Click More Replies times： 4
# Click More Replies times： 5
# Click More Replies times： 6
# Click More Replies times： 7
# Click More Replies times： 8
# Click More Replies times： 9
# Click More Replies times： 10
# Click More Replies times： 11
# Click More Replies times： 12
# Click More Replies times： 13
# Click More Replies times： 14
# Click More Replies times： 15
# Click More Replies times： 16
# Click More Replies times： 17
# Click More Replies times： 18
# Click More Replies times： 19
# Click More Replies times： 20
# Click More Replies times： 21
# Click More Replies times： 22
# Click More Replies times： 23
# Click More Replies times： 24
# Click More Replies times： 25
# Click More Replies times： 26
# Click More Replies times： 27
# Click More Replies times： 28
# Click More Replies times： 29
# Click More Replies times： 30
# Click More Replies times： 31
# Click More Replies times： 32
# Click More Replies times： 33
# Click More Replies times： 34
# Click More Replies times： 35
# Click More Replies times： 36
# Click More Replies times： 37
# Click More Replies times： 38
# Click More Replies times： 39
# Click More Replies times： 40
# Click More Replies times： 41
# Click More Replies times： 42
# Click More Replies times： 43
# Click More Replies times： 44
# Click More Replies times： 45
# Click More Replies times： 46
# Click More Replies times： 47
# Click More Replies times： 48
# Click More Replies times： 49
# Click More Replies times： 50
# Click More Replies times： 51
# Click More Replies times： 52
# Click More Replies times： 53
# Click More Replies times： 54
# Click More Replies times： 55
# Click More Replies times： 56
# Click More Replies times： 57
# Click More Replies times： 58
# Click More Replies times： 59
# Click More Replies times： 60
# Click More Replies times： 61
# Click More Replies times： 62
# Click More Replies times： 63
# Click More Replies times： 64
# Click More Replies times： 65
# Click More Replies times： 66
# Click More Replies times： 67
# Click More Replies times： 68
# Click More Replies times： 69
# Click More Replies times： 70
# Click More Replies times： 71
# Click More Replies times： 72
# Click More Replies times： 73
# Click More Replies times： 74
# Click More Replies times： 75
# Click More Replies times： 76
# Click More Replies times： 77
# Click More Replies times： 78
# Click More Replies times： 79
# Click More Replies times： 80
# Click More Replies times： 81
# Click More Replies times： 82
# Click More Replies times： 83
# Click More Replies times： 84
# Click More Replies times： 85
# Click More Replies times： 86
# Click More Replies times： 87
# Click More Replies times： 88
# Click More Replies times： 89
# Click More Replies times： 90
# Click More Replies times： 91
# Click More Replies times： 92
# Click More Replies times： 93
# Click More Replies times： 94
# Click More Replies times： 95
# Click More Replies times： 96
# Click More Replies times： 97
# Click More Replies times： 98
# Click More Replies times： 99
# Click More Replies times： 100
# Click More Replies times： 101
# Click More Replies times： 102
# Click More Replies times： 103
# Click More Replies times： 104
# Click More Replies times： 105
# Click More Replies times： 106
# Click More Replies times： 107
# Click More Replies times： 108
# Click More Replies times： 109
# Click More Replies times： 110
# Click More Replies times： 111
# Click More Replies times： 112
# Click More Replies times： 113
# Click More Replies times： 114
# Click More Replies times： 115
# Click More Replies times： 116

# %%
# 關閉彈窗
def ClosePopup():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
    time.sleep(1)
    clickNotNow()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    clickNotNow()
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    clickNotNow()

# 選擇按照New或Oldest來顯示留言(選擇最相關或所有留言都不會會真的顯示所有留言)
def ClickOldest():
    time.sleep(2)
    driver.find_element_by_xpath('//a[@data-testid="UFI2ViewOptionsSelector/link"]').click()
    time.sleep(1)
    try:
        driver.find_element_by_partial_link_text('Comments shown in chronological order with the oldest comments at the top.').click()
    except:
        try:
            driver.find_element_by_partial_link_text('New comments and those with new replies appear at the top.').click()
        except:
            print('Plz, Check this post arragne type!')
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()

# 偵測是否有「更多留言」（第一層），若有則點擊
def MoreComments():
    k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 150):
        print('Click More Comments： ' + str(l) + ' times.')
        try:
            driver.find_element_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]').click()
            time.sleep(1)
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))
        except:
            time.sleep(0.1)
        finally:
            l += 1
    time.sleep(1)

# 偵測是否有「更多回覆」（第二層），若有則點擊
def MoreReplies():
    k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 150):
        l += 1
        print('Click More Replies： ' + str(l) + ' times.')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            try:
                i.click()
                time.sleep(0.1)
                clickNotNow()
                k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
            except:
                time.sleep(0.1)
        time.sleep(1)
        
# 偵測是否有「更多回覆」（第二層），若有則點擊
def MoreReplies2():
    k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 150):
        l += 1
        print('Click More Replies： ' + str(l) + ' times.')
        driver.find_element_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]').click()
        time.sleep(1)
        k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
    time.sleep(1)
    
# 打開各篇貼文並展開所有留言 與 留言的留言
def PostExpand():
    ClosePopup()
    ClickOldest()
 
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')

        
        
        
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)

# %%
PostExpand()
# Out:
# Plz, Check this post arragne type!

# %%
soup = BeautifulSoup(driver.page_source)

# %%
PostInfo(soup)
# Out:
#    Name        ID              Time  \
# 0  台灣之星  tstartel  2019-05-25 21:01
#
#                                              Content  Comments  Shares  Likes  \
# 0  想知道走在路上被行注目禮👀的感覺嗎?  明天 #週1福利日 美女速成班 看這👉 http:/...        42       1    225
#
#    Loves  Hahas  Wows  Sads  Angrys        Updatetime  \
# 0      8      0     0     0       0  2019-05-27 01:05
#
#                                                 Link
# 0  https://www.facebook.com/tstartel/photos/a.854...

# %%
# 21                                        我原本有台灣之星手機号  360044337354953
# 22                                  無論是老客戶或是新朋友都可以參加~  100000389140123
# 23           你們家網路真的好快，在我家可以飆到90幾M，有時候100M，台灣之星💪💪💪👍👍👍  360044337354953
# 24                        謝謝您😍😍您的鼓勵是我們變得更好更棒的動力唷(〃ω〃)  100027860342016
# 25                                       你們語音繳費真的好，很爛  360044337354953
# 26           我們也有提供官網或是APP線上繳款~全家、OK、萊爾富便利商店也可以條碼繳費唷!  100014723598455
# 27                       合約快到期了網路真的沒話說越來越爛用到都快砸手機了👎👎👎  360044337354953
# 28  小編建議可以先試試看1⃣將手機背景程式清空2⃣將手機關機約10-15秒再重新開機如果還是沒有...  100012799216492
# 29                                 嘉義縣民雄鄉大崎村的訊號真的好差!!  360044337354953
# 30                                          請正龍看看私訊唷~  100000540202873
# 31                                 網路是要爛幾點的 用了幾年還是沒改善  360044337354953
#
#     RepName                                               Link  \
# 0      台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 1       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 2       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 3       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 4       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 5       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 6       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 7       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 8       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 9       陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 10      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 11      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 12      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 13      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 14      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 15      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 16      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 17      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 18      陳國進  https://www.facebook.com/tstartel/photos/a.854...
# 19     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 20      廖文榮  https://www.facebook.com/tstartel/photos/a.854...
# 21     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 22      廖文榮  https://www.facebook.com/tstartel/photos/a.854...
# 23     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 24     楊杉謙信  https://www.facebook.com/tstartel/photos/a.854...
# 25     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 26      林友前  https://www.facebook.com/tstartel/photos/a.854...
# 27     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 28  Sy Shen  https://www.facebook.com/tstartel/photos/a.854...
# 29     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
# 30       正龍  https://www.facebook.com/tstartel/photos/a.854...
# 31     台灣之星  https://www.facebook.com/tstartel/photos/a.854...
#
#           Updatetime
# 0   2019-05-27 01:14
# 1   2019-05-27 01:14
# 2   2019-05-27 01:14
# 3   2019-05-27 01:14
# 4   2019-05-27 01:14
# 5   2019-05-27 01:14
# 6   2019-05-27 01:14
# 7   2019-05-27 01:14
# 8   2019-05-27 01:14
# 9   2019-05-27 01:14
# 10  2019-05-27 01:14
# 11  2019-05-27 01:14
# 12  2019-05-27 01:14
# 13  2019-05-27 01:14
# 14  2019-05-27 01:14
# 15  2019-05-27 01:14
# 16  2019-05-27 01:14
# 17  2019-05-27 01:14
# 18  2019-05-27 01:14
# 19  2019-05-27 01:14
# 20  2019-05-27 01:14
# 21  2019-05-27 01:14
# 22  2019-05-27 01:14
# 23  2019-05-27 01:14
# 24  2019-05-27 01:14
# 25  2019-05-27 01:14
# 26  2019-05-27 01:14
# 27  2019-05-27 01:14
# 28  2019-05-27 01:14
# 29  2019-05-27 01:14
# 30  2019-05-27 01:14
# 31  2019-05-27 01:14

# %%
for i in :
    print('Dealing with: ' + i)
    
    try:
        PostExpand()
        time.sleep(1)
        print('Expand Succed!')
        try:
            soup = BeautifulSoup(driver.page_source)
            time.sleep(1)
            nPost = PostInfo(soup)
            Posts = UpdateData(DateFrame_o = Posts, DateFrame_n = nPost)
            print('Update PostInfo complete!')
            try:
                nComments = CommentsInfo(soup)
                Comments = UpdateData(DateFrame_o = Comments,DateFrame_n = nComments)
                print('Update CommentsInfo complete!')
            except:
                print('Update CommentsInfo Failed!')
        except:
            print('Crawl Post or Comments Failed!')
    except:
        print('Expand Failed!')
    gc.collect()
    print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '\n\n------------------')

# %%
def CommentsInfo(soup):  
    PostComments = pd.DataFrame()
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    try:
        for i in userContent.select('ul._7a9a > li'):
            # 先抓留言並放在Comment
            Comment = pd.DataFrame(data=[{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                          'Name':i.find('img').attrs['alt'],
                                          'Time':datetime.datetime.strptime(i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                          'Content':Comment_Content(i),
                                          'RepID':userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1],
                                          'RepName':userContent.find('img').attrs['aria-label'],
                                          'Link':driver.current_url}],
                                   columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
            PostComments = pd.concat([PostComments, Comment], ignore_index=True)
            # 留言的留言
            for j in i.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
                Comment = pd.DataFrame(data=[{'ID':j.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'Name':j.find('img').attrs['alt'],
                                              'Time':datetime.datetime.strptime(j.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                              'Content':GetPost_CommentContent(j),
                                              'RepID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'RepName':i.find('img').attrs['alt'],
                                              'Link':driver.current_url}],
                                       columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
                PostComments = pd.concat([PostComments, Comment], ignore_index=True)
        PostComments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
    except:
        print('Crawl Comments Failed!')
    return PostComments

# %%
soup = BeautifulSoup(driver.page_source)
CommentsInfo(soup)
# Out:
# Crawl Comments Failed!
#                 ID Name              Time      Content            RepID  \
# 0  100008036701674  陳國進  2019-05-26 12:44  我今天要去屏東市😆😆😆  360044337354953
#
#   RepName                                               Link
# 0    台灣之星  https://www.facebook.com/tstartel/photos/a.854...

# %%
soup = BeautifulSoup(driver.page_source)
PostInfo(soup)
# Out:
#    Name        ID              Time  \
# 0  台灣之星  tstartel  2019-05-15 22:11
#
#                                              Content  Comments  Shares  Likes  \
# 0  台灣之星2019全新品牌主張 你的電信就該是這個樣子⚡今日登場 全民一起辦活動⚡同步開跑‼️...      1700      88    732
#
#    Loves  Hahas  Wows  Sads  Angrys        Updatetime  \
# 0     12      0     0     0      20  2019-05-27 00:43
#
#                                                 Link
# 0  https://www.facebook.com/tstartel/posts/327440...

# %%
CommentsInfo(soup)
# Out:
#                    ID             Name              Time  \
# 0     100004563705267              李維尼  2019-05-16 13:14
# 1     360044337354953             台灣之星  2019-05-16 13:25
# 2     100003595572374              魏坤輝  2019-05-16 13:33
# 3     360044337354953             台灣之星  2019-05-16 13:57
# 4     100004563705267              李維尼  2019-05-16 14:03
# 5     360044337354953             台灣之星  2019-05-16 14:23
# 6     100004563705267              李維尼  2019-05-16 14:26
# 7     100004563705267              李維尼  2019-05-16 14:39
# 8     360044337354953             台灣之星  2019-05-16 14:50
# 9     100001860123628    Wu Hung Chuan  2019-05-16 13:15
# 10    360044337354953             台灣之星  2019-05-16 13:21
# 11    100001860123628    Wu Hung Chuan  2019-05-16 13:22
# 12    360044337354953             台灣之星  2019-05-16 13:38
# 13    100001860123628    Wu Hung Chuan  2019-05-16 13:49
# 14    360044337354953             台灣之星  2019-05-16 14:11
# 15         1546887115      Michael Lee  2019-05-16 13:17
# 16    360044337354953             台灣之星  2019-05-16 13:27
# 17    100000464033628              蕭仲程  2019-05-16 15:20
# 18    360044337354953             台灣之星  2019-05-16 15:43
# 8     行動網路容易受使用地點附近的房屋密集度、建築裝潢使用材質、附近使用人數多寡…等等因素影響，我...  100004563705267
# 9     499沒有比較划算，你們的費率本來就超過1分1元，會打到499的算起來還是499為什麼要辦4...  360044337354953
# 10                    網路門市申請只要299，趕快樓上邀樓下~一起到網路門市新辦一門吧😘  100001860123628
# 11                                                 雞同鴨講  100001860123628
# 12    每個專案的優惠內容提供給不同的消費群族來多元選擇，所以除了499以外也可以參考188、599...  100001860123628
# 13             辦299打到499分也是付499499的方案 少打又不能退錢每個月還要多繳200  100001860123628
# 14    聰明的尼可以依照您的需求來選擇唷!!!ps.2⃣9⃣9⃣是網路門市限定的，只能在網路門市申辦唷!!  100001860123628
# 15                            問好幾週都沒有回覆，早就已經去別家，真是太爛了⋯⋯  360044337354953
# 16                                                  img       1546887115
# 17                                   Michael Lee 問什麼問題？       1546887115
# 18                               Michael是否可以給小編一點線索~~~~       1546887115
# 19                                        反正舊客戶不准申請就對了！  360044337354953
# 20             個人用戶最多可以申辦三門月租，新辦一門也很划算唷~😘還可以推薦家人來申請唷~~❤  100007124430949
# 21                                      台灣之星 舊客戶不能續約啊==  100007124430949
# 22                                               小編私訊囉~  100007124430949
# 23                                         我也是舊客戶以達續約條件  100007124430949
# 24                                           快看看小編的悄悄話~  100007124430949
# 25                                    台灣之星 我也是舊客戶以達續約條件  100007124430949
# 26                                       小編也傳送私訊給Hero囉~  100007124430949
# 27                                      反正舊客戶不准申請就對了！+1  360044337354953
# 28                                    這麼優惠的方案再辦一門也很划算唷~  100000302345116
# 29      台灣之星 小編這回答很扣分欸...沒事誰會要這麼多門號啦，你們也要顧顧老客戶，不然約到也想跳了  100000302345116
# ...                                                 ...              ...
# 1600                                       請問是客服信箱的界面對嗎  100001223965249
# 1601                                    沒錯喔~~~留下線索給我們吧😁  100001223965249
# 1602                                             老客戶續約?  360044337354953
# 1603                                        續約朋友來看看私訊吧🤓  100028268082983
# 1604                                     預付卡可以原門號辦299嗎？  360044337354953
# 1605                   預付卡轉月租門號透過實體門市~~建議您可以參考實體門市優惠喔💛💛  100000120151751
# 1606                                  續約的可以有這個299專案一樣的嗎  360044337354953
# 1607                                           已私訊名彥◕‿◕  100030271273213
# 1608                                           續約可以申辦嗎？  360044337354953
# 1609                                        私訊給我們點線索吧🕵🕵  100000426452673
# 1610                                         老客戶可續約次方案嗎  360044337354953
# 1611                                        去看看小編說了什麼吧😍  100000218472823
# 1612  請問299方案，預繳1200是每個月扣299嗎？若今天選宅配申請，約多久會收件呢？及多久可開...  360044337354953
# 1613  💛預繳金分期抵扣，每期扣50元💛網路門市平均配送時間1-3工作天💛新申辦2小時內開通💛攜碼4...  100016165326848
# 1614  老客戶想續約到門市詢問客服人員說網路門市辦理續約會比較優惠但是在台灣之星app找了半天也不得...  360044337354953
# 1615  來看看這裡~~就可以辦理囉🤩https://shop.tstartel.com/detail...  100000078365885
# 1616  老客戶想續約到門市詢問客服人員說網路門市辦理續約會比較優惠但是在台灣之星app找了半天也不得...  360044337354953
台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 34           周書楷  https://www.facebook.com/tstartel/posts/328473...
# 33          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 32           陳秋蘭  https://www.facebook.com/tstartel/posts/328473...
# 31          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 30    Long Chang  https://www.facebook.com/tstartel/posts/328473...
# 13           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 14           史考特  https://www.facebook.com/tstartel/posts/328473...
# 15          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 16           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 17           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 18           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 19           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 20          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 21           林群智  https://www.facebook.com/tstartel/posts/328473...
# 22           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 23          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 29          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 25          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 26           李梓豪  https://www.facebook.com/tstartel/posts/328473...
# 24            曾翔  https://www.facebook.com/tstartel/posts/328473...
#
#           Updatetime
# 48  2019-05-20 23:47
# 61  2019-05-20 23:47
# 70  2019-05-20 23:47
# 69  2019-05-20 23:47
# 68  2019-05-20 23:47
# 67  2019-05-20 23:47
# 66  2019-05-20 23:47
# 65  2019-05-20 23:47
# 64  2019-05-20 23:47
# 63  2019-05-20 23:47
# 62  2019-05-20 23:47
# 60  2019-05-20 23:47
# 72  2019-05-20 23:47
# 59  2019-05-20 23:47
# 58  2019-05-20 23:47
# 57  2019-05-20 23:47
# 56  2019-05-20 23:47
# 55  2019-05-20 23:47
# 54  2019-05-20 23:47
# 53  2019-05-20 23:47
# 52  2019-05-20 23:47
# 51  2019-05-20 23:47
# 71  2019-05-20 23:47
# 73  2019-05-20 23:47
# 49  2019-05-20 23:47
# 85  2019-05-20 23:47
# 94  2019-05-20 23:47
# 93  2019-05-20 23:47
# 92  2019-05-20 23:47
# 91  2019-05-20 23:47
# ..               ...
# 12  2019-05-20 23:46
# 0   2019-05-20 23:46
# 28  2019-05-20 23:45
# 27  2019-05-20 23:45
# 40  2019-05-20 23:45
# 39  2019-05-20 23:45
# 38  2019-05-20 23:45
# 37  2019-05-20 23:45
# 36  2019-05-20 23:45
# 35  2019-05-20 23:45
# 34  2019-05-20 23:45
# 33  2019-05-20 23:45
# 32  2019-05-20 23:45
# 31  2019-05-20 23:45
# 30  2019-05-20 23:45
# 13  2019-05-20 23:45
# 14  2019-05-20 23:45
# 15  2019-05-20 23:45
# 16  2019-05-20 23:45
# 17  2019-05-20 23:45
# 18  2019-05-20 23:45
# 19  2019-05-20 23:45
# 20  2019-05-20 23:45
# 21  2019-05-20 23:45
# 22  2019-05-20 23:45
# 23  2019-05-20 23:45
# 29  2019-05-20 23:45
# 25  2019-05-20 23:45
# 26  2019-05-20 23:45
# 24  2019-05-20 23:45
#
# [96 rows x 8 columns]

# %%
driver.quit()

# %% [markdown]
# # 其他

# %%
# 原本想要登入的方式獲取連結，但FB會偵測異常行為，暫時先不登入
# 關閉Chrome的「通知」提醒
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-notifications")

driver = webdriver.Chrome(options=chrome_options)
url = 'https://www.facebook.com/'
driver.get(url)
time.sleep(3)

# 啟動瀏覽器並登入Facebook
username = driver.find_element_by_id('email')
username.send_keys('61034b001@gms.ndhu.edu.tw')
passwd=driver.find_element_by_id('pass')
passwd.send_keys('19920309')
button=driver.find_element_by_id('loginbutton')
button.click()
