# %% [markdown]
# # Facebook爬蟲

# %% [markdown]
# # 定義函數供後續使用

# %% [markdown]
# 在這裡我們先定義一個函數，希望把網頁中各篇貼文的連結都找出來!
# ulr放我們要爬的Facebook網址，n是稍後要送出幾次滾動網頁到底部的命令，藉以加載更多資料。

# %%
def FindLinks(url, n):
    Links = []
    driver.get(url)
    for i in range(n):
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
    driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    soup = BeautifulSoup(driver.page_source)
    posts = soup.findAll('div', {'class':'clearfix y_c3pyo2ta3'})
    for i in posts:
        Links.append('https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0])
    return Links

# %% [markdown]
# 定義一個展開所有留言的函數，透過while迴圈反覆搜尋與點擊「看更多留言」、「看更多回覆」與「看完整貼文內容」等按鈕。
# 在過程中會出現請我們登入或註冊的彈跳視窗，但我們不確定到底什麼時候會跳出，因此需要在過程中反覆偵測是有出現這個彈窗，若有就點擊「Not Now」

# %%
# 展開url中的所有留言 與 留言的留言
def expand(url):
    driver.get(url)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    try:
        driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        driver.find_element_by_id('expanding_cta_close_button').click() 
    except:
        time.sleep(1)
    # 偵測是否有「更多留言」（第一層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                driver.find_element_by_id('expanding_cta_close_button').click()
            except:
                time.sleep(0.5)            
            try:
                i.click()
            except:
                time.sleep(0.5)   
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                driver.find_element_by_id('expanding_cta_close_button').click()
            except:
                time.sleep(0.5)
            try:
                i.click()
            except:
                time.sleep(0.5)
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
            except:
                time.sleep(0.5)

# %% [markdown]
# 透過逐層搜索的方式，逐步定位我們要找的資訊
# 在這個環節需要反覆透過Chrome的功能比對資料，需要花一些心力進行比對
# 另外在這部分也使用了大量個try-except，原因是許多資料是有內容才會出現。例如並非每天貼人都會收到「哈哈」、「生氣」的心情。

# %%
# 文章內容與互動摘要
def CrawlPost(soup):
    time.sleep(1)
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # po文人資訊區塊
    PosterInfo = userContent.find('div', {'class':'l_c3pyo2v0u i_c3pynyi2f clearfix'})
    # 互動摘要區(讚、留言與分享)
    feedback = soup.find('form', {'class':'commentable_item collapsed_comments'})
    # 名稱
    Name = PosterInfo.find('img').attrs['aria-label']
    # ID
    ID = PosterInfo.find('a', {'class':'_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe'}).attrs['href'].split('/?',2)[0].split('/',-1)[-1]
    # 網址
    Link = driver.current_url
    # 發文時間
    try:
        Time = PosterInfo.find('abbr').attrs['title']
    except:
        Time = PosterInfo.find('div', {'class':'_1atc fsm fwn fcg'}).text
    # 文章內容
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = ""
    # Like
    try:
        Like = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Like = '0' 
    # Love
    try:
        Love = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_LOVE'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Love = '0' 
    # Haha
    try:
        Haha = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Haha = '0' 
    # Wow
    try:
        Wow = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_WOW'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Wow = '0' 
    # Sad
    try:
        Sad = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_SORRY'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Sad = '0' 
    # Angry
    try:
        Angry = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Angry = '0'
    # 留言
    try:
        Comments = feedback.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
    except:
        Comments = '0' 
    # 分享
    try:
        Share = feedback.find('span', {'class':'_355t _4vn2'}).text.split(' ',2)[0]
    except:
        Share = '0' 
    Updatetime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return pd.DataFrame(
        data = [{'Name':Name,
                 'ID':ID,
                 'Link':Link,
                 'Time':Time,
                 'Content':Content,
                 'Like':Like,
                 'Love':Love,
                 'Haha':Haha,
                 'Wow':Wow,
                 'Sad':Sad,
                 'Angry':Angry,
                 'Comments':Comments,
                 'Share':Share,
                 'Updatetime':Updatetime}],
        columns = ['Name', 'ID', 'Time', 'Content', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Comments', 'Share', 'Link', 'Updatetime'])

# %% [markdown]
# 這邊要留意雖然都是粉絲留言，但實際上分成「回應貼文的留言」與「回應留言的留言」。
# 函數中的第一個迴圈是用來抓「回應貼文的留言」，第二個則是抓「回應留言的留言」。讀者可以自行比較一下兩個迴圈中不同的地方。

# %%
# 留言
def CrawlComment(soup):
    time.sleep(1)
    Comments = pd.DataFrame()
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 用戶留言區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 回應貼文的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_0'}):
        try:
            Content = i.find('span', {'dir':'ltr'}).text
        except:
            Content = 'sticker'
        Comment = pd.DataFrame(data = [{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'Name':i.find('img').attrs['alt'],
                                 'Time':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'Content':Content,
                                 'Link':driver.current_url}],
                        columns = ['ID', 'Name', 'Time', 'Content', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)
    
    # 回應留言的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
        try:
            Content = i.find('span', {'dir':'ltr'}).text
        except:
            Content = 'sticker'
        Comment = pd.DataFrame(data = [{'ID':i.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'Name':i.find('img').attrs['alt'],
                                 'Time':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'Content':Content,
                                 'Link':driver.current_url}],
                        columns = ['ID', 'Name', 'Time', 'Content', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)
    Comments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return Comments

# %% [markdown]
# # 組合應用
# 組合以上函數，針對逐一爬取List中的貼文，依據貼文的類型做後續處理
#
# - 新貼文：爬取貼文與留言
# - 舊貼文但有新留言：更新貼文摘要並爬取留言
# - 舊貼文且無新留言：pass
# - 其他：查看情況

# %% [markdown]
# ## 台星

# %%
url = 'https://www.facebook.com/tstartel/'
Links = FindLinks(url = url, n = 15)
# 抓下來所有留言
for i in Links:
    print('Dealing with: ' + i)
    try:
        driver.get(i)
        time.sleep(1)
        soup = BeautifulSoup(driver.page_source)
        # 檢視文章摘要，分成全新文章、舊文章但有新留言、舊文章也無新留言
        nPost = CrawlPost(soup)
        compare = pd.merge(left = nPost.loc[:,['Link', 'Comments']] ,
                           right = Posts.loc[:,['Link', 'Comments']],
                           how = 'inner',
                           on = ['Link'],
                           indicator=True,
                           suffixes=('_n', '_o'))
        # 新貼文直接爬留言
        if len(compare) == 0:
            print('Type: ' + 'New Post')
            expand(i)
            soup = BeautifulSoup(driver.page_source)
            nComments = CrawlComment(soup)
        # 舊文章但有新留言，僅保留新的留言(drop掉已經在資料庫的資料)
        elif compare.Comments_n.values > compare.Comments_o.values:
            # 開始爬留言並將文章摘要匯入
            print('Type: ' + 'Old Post with New Comments')
            expand(i)
            soup = BeautifulSoup(driver.page_source)
            nComments = CrawlComment(soup)
            nComments = pd.merge(left = nComments,
                                 right = Comments,
                                 how = 'left',
                                 on = ['ID', 'Name', 'Content', 'Link'],
                                 suffixes=('', '_o'),
                                 indicator=True)
            nComments = nComments.loc[nComments._merge == 'left_only',:]
            nComments = nComments.drop(['Time_o', 'Updatetime_o', '_merge'], axis=1)
        # 舊文章也無新留言，pass過去
        elif compare.Comments_n.values == compare.Comments_o.values:
            print('Type: ' + 'Old Post with Old Comments')
            nComments = pd.DataFrame()
        # 其他狀況，請釐清問題
        else:
            print('Type: ' + 'Uncertain condiction! Plz Check this website:' + '...')
            nComments = pd.DataFrame()        
        
        # post的資料直接concat在最下面，並duplicate掉，藉以更新互動摘要
        Posts = pd.concat([Posts, nPost], ignore_index=True)
        Posts = Posts.sort_values(by = 'Updatetime', ascending = False)
        Posts = Posts.drop_duplicates(subset ="Link",
                                      keep= 'first',
                                      inplace = False) 
        Comments = pd.concat([Comments, nComments], ignore_index=True, sort=False)
        print('Result: Succed!')
        print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        print('----------------------------------------------------------')
        print('\n')
    except:
        print('Result: Failed!')
        print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        print('----------------------------------------------------------')
        print('\n')
Posts.to_csv('C:/Users/TL_Yu/Desktop/Posts.csv',index = False)
Comments.to_csv('C:/Users/TL_Yu/Desktop/Comments.csv',index = False)
# Out:
# Dealing with: https://www.facebook.com/tstartel/videos/321955001812559/
# Type: New Post
# Result: Succed!
# Time Log: 2019-05-15 22:14:47
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3269351643090860
# Type: Uncertain condiction! Plz Check this website:...
# Result: Succed!
# Time Log: 2019-05-15 22:14:51
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3267141889978502
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:17
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3259789660713725/
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:32
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3264107533615271/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:35
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3261515247207833
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:39
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3259344244091600
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:43
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3259397344086290/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3254254444600580
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3254038111288880
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:54
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3251586194867405
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3249335421759149/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3246516712041020/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3243531712339520/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:09
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3243588789000479/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:13
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3241649495861075/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3238717112820980/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:20
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3236285659730792/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:23
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3234262259933132/
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:38
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3234388456587179/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:42
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/356966824846946/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3231419526884072
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3229153237110701/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:53
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3224660157560009
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3224692507556774/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:00
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3222529091106449/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:04
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3220095821349776/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:08
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3217437468282278/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:12
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3217249391634419/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/383716782215026/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:20
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3214817948544230/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:24
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2393598470666186/3209498659076159/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:28
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3206630172696341
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:32
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3204484132910945/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:35
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3202371059788919/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:39
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3200691366623555/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:43
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3199870890038936/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3199637973395561
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3197740693585289/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:53
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3194840400541985
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2482674201758612/3192347447457947/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/1285036481654086/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3188207417871950
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:09
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3188462841179741
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:12
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3188045531221472/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3187497977942894/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:19
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3185771428115549/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:23
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3183171725042186/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:27
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3180842608608431
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:31
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3179553862070639/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:34
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3178469558845736/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:38
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3178385162187509
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:41
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3176156975743661/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:47
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3173678422658183/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:51
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3169485439744148/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:54
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3168948736464485
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:58
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3166649270027765
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3164522346907124/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/589662731510587/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:10
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3161535820539110/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:14
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3159082294117796/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:17
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3156987667660592/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:21
# ----------------------------------------------------------

# %% [markdown]
# # Crawl2.0

# %%
import pandas as pd
import re, time, requests, datetime, gc
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# # 截取塗鴉墻貼文資訊並比對先前資料
# 如果每次都把所有貼文抓下來，無疑會浪費程式效能，在這裡我將載入先前的資料，並將各篇貼文分成以下三類：
#
# - **新貼文**：截取貼文內容與留言
# - **舊貼文但有新留言**：截取所有留言但只將新留言加入資料庫
# - **舊貼文也無新留言**：不處理
#
# 可想而知，如果設定排程每天執行，大多數資料都會是「舊貼文也無新留言」的類型，加入這個判斷機制將大幅節省系統效能

# %%
# 截取塗鴉墻上貼文的留言數
def GetWall_PostCommentCounts(i):
    try:
        CommentCounts = i.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0
    return CommentCounts

# 截取塗鴉墻上貼文的連結
def GetWall_PostLink(i):
    Link = 'https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0]
    return Link

# 截取塗鴉墻上貼文的發佈時間
def GetWall_PostTime(i):
    try:
        Time = i.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = 'Not Post'
    return Time

def CarwlList(urls, n, Posts):
    CheckList = pd.DataFrame(columns = ['Link','Time','CommentCounts']) 
    for i in urls:
        driver.get(i)
        for i in range(n):
            try:
                driver.find_element_by_css_selector('a.pam.uiBoxLightblue.uiMorePagerPrimary').click() # 加載更多貼文的按鈕
            except:
                time.sleep(2)
            # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
            try:
                driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
            except:
                time.sleep(0.5)
            soup = BeautifulSoup(driver.page_source)
            for i in soup.find_all('div', {'class':'_5pcr userContentWrapper'}):
                CheckList = pd.concat([CheckList, pd.DataFrame(data = [{'Link':GetWall_PostLink(i),
                                                                        'Time':GetWall_PostTime(i),
                                                                        'CommentCounts':GetWall_PostCommentCounts(i)}],
                                                                 columns = ['Link','Time','CommentCounts'])],
                                       ignore_index = True)
    
    CarwlList = pd.merge(left = CheckList,
                         right = Posts.loc[:,['Link','CommentCounts']],
                         how='left',
                         on='Link',
                         suffixes=('_c', '_p'),
                         indicator=True)
    CarwlList = pd.concat([CarwlList.loc[CarwlList._merge == 'left_only', :], # 新貼文
                           CarwlList.loc[CarwlList.CommentCounts_c > CarwlList.CommentCounts_p, :]], # 舊貼文但有新留言
                          ignore_index=True)
    CarwlList = CarwlList.drop_duplicates(subset = 'Link',
                                          keep= 'first',
                                          inplace = False)
    return CarwlList

# %% [markdown]
# # 爬取特定貼文的內容與留言
# ## 展開貼文與留言

# %%
# 點擊不要現在註冊帳號
def clickNotNow():
    try:
        driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    except:
        time.sleep(1)

# 將顯示的留言從系統推薦改成所有留言

def ClosePopup():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()
    time.sleep(0.5)
    clickNotNow()
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()
    # 留言排序選new才能抓到全部留言，
    
    # driver.find_element_by_xpath('//a[@data-testid="UFI2ViewOptionsSelector/link"]').click()
    # time.sleep(0.5)
    # try:
    #     driver.find_element_by_partial_link_text('Comments shown in chronological order with the oldest comments')
    # except:
    #     try:
    #         driver.find_element_by_partial_link_text('New comments and those with new replies appear')
    #     except:
    #         print('Plz, Checkthe post arragne type!')

# 打開各篇貼文並展開所有留言 與 留言的留言

def PostExpand():
    time.sleep(2)
    # 偵測是否有「更多留言」（第一層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)   
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)

# %% [markdown]
# ## 爬取貼文內容與留言資訊

# %%
# 貼文留言數
def GetPost_PosterName(userContent):
    return userContent.find('img').attrs['aria-label']

# 貼文留言數
def GetPost_PosterID(userContent):
    return userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1]

# 貼文時間
def GetPost_PostTime(userContent):
    try:
        Time = userContent.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = "Error, Please check this post's condiction!" 
    return Time

# 貼文內容
def GetPost_PostContent(userContent):
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = "There's No Text Content!"
    return Content

# 貼文留言數
def GetPost_PostCommentCounts(userContent):
    try:
        CommentCounts = userContent.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0 
    return CommentCounts

# 貼文分享數
def GetPost_PostShareCounts(userContent):
    try:
        ShareCounts = userContent.find('span', {'class':'_355t _4vn2'}).text.split(' ',2)[0]
        if 'K' in ShareCounts:
            ShareCounts = int(float(ShareCounts.split('K')[0])*1000)
        else:
            ShareCounts = int(ShareCounts)
    except:
        ShareCounts = 0
    return ShareCounts

# 貼文按讚心情數
def GetPost_PostLikeCounts(userContent):
    try:
        LikeCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LikeCounts:
            LikeCounts = int(float(LikeCounts.split('K')[0])*1000)
        else:
            LikeCounts = int(LikeCounts)
    except:
        LikeCounts = 0
    return LikeCounts

# 貼文愛心心情數
def GetPost_PostLoveCounts(userContent):
    try:
        LoveCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LOVE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LoveCounts:
            LoveCounts = int(float(LoveCounts.split('K')[0])*1000)
        else:
            LoveCounts = int(LoveCounts)
    except:
        LoveCounts = 0
    return LoveCounts

# 貼文哈哈心情數
def GetPost_PostHahaCounts(userContent):
    try:
        HahaCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in HahaCounts:
            HahaCounts = int(float(HahaCounts.split('K')[0])*1000)
        else:
            HahaCounts = int(HahaCounts)
    except:
        HahaCounts = 0
    return HahaCounts

# 貼文Wow心情數
def GetPost_PostWowCounts(userContent):
    try:
        WowCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_WOW'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in WowCounts:
            WowCounts = int(float(WowCounts.split('K')[0])*1000)
        else:
            WowCounts = int(WowCounts)
    except:
        WowCounts = 0
    return WowCounts

# 貼文Sad心情數
def GetPost_PostSadCounts(userContent):
    try:
        SadCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_SORRY'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in SadCounts:
            SadCounts = int(float(SadCounts.split('K')[0])*1000)
        else:
            SadCounts = int(SadCounts)
    except:
        SadCounts = 0
    return SadCounts

# 貼文Angry心情數
def GetPost_PostAngryCounts(userContent):
    try:
        AngryCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in AngryCounts:
            AngryCounts = int(float(AngryCounts.split('K')[0])*1000)
        else:
            AngryCounts = int(AngryCounts)
    except:
        AngryCounts = 0
    return AngryCounts

# 留言時間
def GetPost_CommentTime(element):
    Time = element.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content']
    Time = datetime.datetime.strptime(Time, '%A, %b %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M")
    return Time

# 留言內容
def GetPost_CommentContent(element):
    try:
        Content = element.find('span', {'dir':'ltr'}).text
    except:
        Content = 'img'
    return Content

# 文章內容與互動摘要
def PostInfo(soup):
    # 貼文區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    PostContent = pd.DataFrame(data = [{'Name':GetPost_PosterName(userContent),
                                    'ID':GetPost_PosterID(userContent),
                                    'Time':GetPost_PostTime(userContent),
                                    'Content':GetPost_PostContent(userContent),
                                    'CommentCounts':GetPost_PostCommentCounts(userContent),
                                    'Shares':GetPost_PostShareCounts(userContent),
                                    'Like':GetPost_PostLikeCounts(userContent),
                                    'Love':GetPost_PostLoveCounts(userContent),
                                    'Haha':GetPost_PostHahaCounts(userContent),
                                    'Wow':GetPost_PostWowCounts(userContent),
                                    'Sad':GetPost_PostSadCounts(userContent),
                                    'Angry':GetPost_PostAngryCounts(userContent),
                                    'Updatetime':datetime.datetime.now().strftime("%Y-%m-%d %H:%M"),
                                    'Link':driver.current_url,}],
                            columns = ['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
    return PostContent

def PostComments(soup):  
    PostComments = pd.DataFrame()
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    try:
        for i in userContent.select('ul._7a9a > li'):
            # 先抓留言並放在Comment
            Comment = pd.DataFrame(data=[{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                          'Name':i.find('img').attrs['alt'],
                                          'Time':datetime.datetime.strptime(i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                          'Content':GetPost_CommentContent(i),
                                          'RepID':userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1],
                                          'RepName':userContent.find('img').attrs['aria-label'],
                                          'Link':driver.current_url}],
                                   columns = ['ID', 'Name', 'Time', 'Content','RepID','RepName','Link'])
            PostComments = pd.concat([PostComments, Comment], ignore_index=True)
            # 留言的留言
            for j in i.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
                Comment = pd.DataFrame(data=[{'ID':j.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'Name':j.find('img').attrs['alt'],
                                              'Time':datetime.datetime.strptime(j.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                              'Content':GetPost_CommentContent(j),
                                              'RepID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'RepName':i.find('img').attrs['alt'],
                                              'Link':driver.current_url}],
                                       columns = ['ID', 'Name', 'Time', 'Content','RepID','RepName','Link'])
                PostComments = pd.concat([PostComments, Comment], ignore_index=True)
        PostComments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
    except:
        print('Crawl Comments Failed!')
    return PostComments

# %% [markdown]
# # 更新貼文與留言資訊
# 將最新抓到的貼文併回Post表格，並以ID與Time作為關鍵(key)值，取最新抓取的資料(Updatetime)

# %%
def UpdateData(DateFrame_o,DateFrame_n):
    DataFrame = pd.concat([DateFrame_o, DateFrame_n], ignore_index=True)
    DataFrame = DataFrame.sort_values(by = 'Updatetime', ascending = False)
    DataFrame = DataFrame.drop_duplicates(subset = ['ID', 'Time'],
                                          keep= 'first',
                                          inplace = False)
    return DataFrame

# %% [markdown]
# # 爬資料
# ## 讀取先前資料
# 若在桌面偵測不到檔案，就創造新的dataframe

# %%
try:
    Posts = pd.read_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
try:
    Comments = pd.read_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'Rep
# [496 rows x 5 columns]

# %% [markdown]
# 如同上面的說明，當CheckLists「merge」欄位為「left_only」時表示該貼文是新貼文；
#
# 而當「merge」欄位為「both」，但「Comments_c」的值大於「Comments_p」時，表示該貼文是舊資料但有新留言。
#
# 以下將截取這兩類的貼文作為爬取清單

# %% [markdown]
# ## 執行爬蟲

# %%
for i in CarwlList.Link:
    print('Dealing with: ' + i)
    driver.get(i)
    try:
        ClosePopup()
        PostExpand()
        try:
            soup = BeautifulSoup(driver.page_source)
            nPost = PostInfo(soup)
            nComments = PostComments(soup)
            try:
                Posts = UpdateData(DateFrame_o = Posts, DateFrame_n = nPost)
                Comments = UpdateData(DateFrame_o = Comments,DateFrame_n = nComments)
                print('Update Succed!')
            except:
                print('Update Posts or Comments Failed!')
        except:
            print('Crawl Post or Comments Failed!')
    except:
        print('No, Comments, Plz Check this post!')
    gc.collect()
    print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '\n\n------------------')
# Out:
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3241649495861075/
# Update Succed!
# Time Log: 2019-05-21 15:39:50
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3236285659730792/
# Update Succed!
# Time Log: 2019-05-21 15:40:13
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/3188462841179741
# Update Succed!
# Time Log: 2019-05-21 15:40:40
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/589662731510587/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:40:45
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/402346110331390/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:40:50
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/3133707396655286
# Update Succed!
# Time Log: 2019-05-21 15:41:01
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/3101774239848602
# Update Succed!
# Time Log: 2019-05-21 15:41:21
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/422421851841011/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:41:25
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/371588343427008/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:41:30
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2720795567950068
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:41:34
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2722488054447486/
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Update Succed!
# Time Log: 2019-05-21 15:41:42
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2715269541836004/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:41:46
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2703335766362715
# Update Succed!
# Time Log: 2019-05-21 15:41:55
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/663589520750150/
# Update Succed!
# Time Log: 2019-05-21 15:42:04
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2673077649388527/
# Update Succed!
# Time Log: 2019-05-21 15:42:11
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E5%BF%AB%E4%BE%86%E4%B8%80%E8%B5%B7%E4%BA%AB%E7%94%A8hami%E7%93%9C%E5%B8%B6%E4%BE%86%E5%A5%BD%E5%BA%B7%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2741451985881855/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:17
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E6%B8%85%E6%98%8E%E9%80%A3%E5%81%87%E8%8F%AF%E7%B7%A8%E6%94%BE%E5%81%87%E7%A7%98%E7%AC%88%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2725299120830475/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:22
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/hami-%E8%80%81%E5%B8%AB%E7%9A%84%E6%9C%89%E7%8D%8E%E5%BE%B5%E7%AD%94%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2714190525274668/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:27
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2625898320773127/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:31
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E6%A6%AE%E7%8D%B2%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9F%E4%B8%89%E5%86%A0%E7%8E%8B%E5%8F%B0%E4%B8%AD%E6%B0%B8%E7%A6%8F%E5%8F%8A%E9%AB%98%E9%9B%84%E4%BA%94%E7%A6%8F%E9%96%80%E5%B8%82%E9%99%90%E5%AE%9A%E5%8A%A0%E7%A2%BC%E6%8A%BD%E7%8D%8E%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2706220829404971/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:36
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2621480854548207
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:40
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2627346870628272/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:45
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2624215924274700/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:49
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2614263715269921/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:42:53
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2601190549910571/
# Update Succed!
# Time Log: 2019-05-21 15:43:01
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E6%A6%AE%E7%8D%B2%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9F%E4%B8%89%E5%86%A0%E7%8E%8B%E5%8F%B0%E5%8C%97%E5%A8%81%E7%A7%80%E9%96%80%E5%B8%82%E9%99%90%E5%AE%9A%E5%8A%A0%E7%A2%BC%E6%8A%BD%E7%8D%8E%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2662848237075564/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:43:05
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E7%B2%89%E7%B5%B2%E9%99%90%E5%AE%9A%E5%85%83%E5%AE%B5%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2656547634372291/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:43:11
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2581775801852046/
# Update Succed!
# Time Log: 2019-05-21 15:43:19
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/558948321256016/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:43:23
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E7%B2%89%E7%B5%B2%E8%B5%B0%E6%98%A5%E5%A5%BD%E7%A6%AE%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2648382135188841/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-21 15:43:28
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2545236988839261/
# Update Succed!
# Time Log: 2019-05-21 15:43:36
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/
pickle('C:/Users/TL_Yu/Desktop/Comments.plk')

# %%
Posts.to_excel('C:/Users/TL_Yu/Desktop/Posts.xlsx')
Comments.to_excel('C:/Users/TL_Yu/Desktop/Comments.xlsx')
# Out:
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3161535820539110/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3164522346907124/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3168948736464485' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3169485439744148/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3166649270027765' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3178385162187509' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3176156975743661/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.2512681442091221/3173678422658183/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3178469558845736/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3179553862070639/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3180842608608431' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3183171725042186/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3188045531221472/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3185771428115549/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3187497977942894/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3188207417871950' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3194840400541985' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/videos/1285036481654086/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.2482674201758612/3192347447457947/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3197740693585289/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3199870890038936/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3199637973395561' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3202371059788919/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3200691366623555/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3204484132910945/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3206630172696341' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.2393598470666186/3209498659076159/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/videos/383716782215026/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3214817948544230/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3217437468282278/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3217249391634419/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3220095821349776/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3224692507556774/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3222529091106449/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3224660157560009' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3231419526884072' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3229153237110701/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/videos/356966824846946/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3234262259933132/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.2512681442091221/3234388456587179/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3238717112820980/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.2512681442091221/3249335421759149/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3243588789000479/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3243531712339520/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3246516712041020/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3251586194867405' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3254038111288880' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3254254444600580' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3259397344086290/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3259344244091600' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3267141889978502' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3261515247207833' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3259789660713725/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3264107533615271/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/videos/321955001812559/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3269351643090860' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3274403725918985' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3277132165646141/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/posts/3276845979008093' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.854369967922385/3277739692252055/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3275222502503774/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\xlsxwriter\worksheet.py:918: UserWarning: Ignoring URL 'https://www.facebook.com/tstartel/photos/a.413576055335114/3277738568918834/' since it exceeds Excel's limit of 65,530 URLS per worksheet.
#   "65,530 URLS per worksheet." % force_unicode(url))

# %% [markdown]
# # 維護測試區

# %%
try:
    Posts = pd.read_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
try:
    Comments = pd.read_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName','Link', 'Updatetime'])
    
urls = ['https://www.facebook.com/tstartel/',
        'https://www.facebook.com/chtmobile/',
        'https://www.facebook.com/taiwanmobile/',
        'https://www.facebook.com/fareastone/',
        'https://www.facebook.com/Aptg.tw/']

# %%
driver = webdriver.Chrome()
driver.get('https://www.facebook.com/')
# print(driver.get_cookies())
driver.delete_all_cookies()
driver.add_cookie({'domain': '.facebook.com', 'expiry': 1558752322, 'httpOnly': False, 'name': 'locale', 'path': '/', 'secure': True, 'value': 'en_US'})

# %%
https://www.facebook.com/tstartel/photos/a.854369967922385/3277739692252055/
# Out:
# a
# b
# c
# d
# e
# f
# Expand Post Comments Succed!a

# %%
driver.get('https://www.facebook.com/tstartel/photos/a.413576055335114/3275228019169889/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c5cd90142681> in <module>()
# ----> 1 driver.get('https://www.facebook.com/tstartel/photos/a.413576055335114/3275228019169889/')
#
# NameError: name 'driver' is not defined

# %%
ClosePopup()

# %%
PostExpand()

# %%
soup = BeautifulSoup(driver.page_source)
nPost = PostInfo(soup)
nComments = PostComments(soup)

# %%
nPost
# Out:
#          Name               ID              Time  \
# 0  亞太電信Gt智慧生活  162174107155573  2019-05-17 20:00
#
#                                              Content  CommentCounts  Shares  \
# 0  《三國演義-最強武將傳》亞太電信小額付費代收‼ 最強在此，誰敢來戰😎  史詩級戰爭手遊 《三...            415     322
#
#    Like  Love  Haha  Wow  Sad  Angry        Updatetime  \
# 0   423     1     0    0    0      0  2019-05-21 00:57
#
#                                                 Link
# 92                                       台灣之星 你不是公仔嗎？  100025965258813
# 91                           美女是在叫小編嗎❤❤大美女晚安(๑˃̵ᴗ˂̵)ﻭ  100025965258813
# ..                                                ...              ...
# 12                                           舊用戶可以買嗎？  360044337354953
# 0                                      老客戶也可以唷(๑´ڡ`๑)  100000270862585
# 28                                        大家一起動起來~~😊😊  100000401712214
# 27               現在是收訊跟網路有異常嗎？ 為什麼我的收訊只有一格...平常都不會這樣啊  360044337354953
# 40                                     一樣收訊跟網路都變的很慢⋯⋯  100000950539467
# 39  可是我前幾天在清洗用過的（沾到油）塑膠袋時，用掉的水和清潔劑讓我對人生產生問號。@@竹筷我覺...  360044337354953
# 38                 選擇好清洗且可重複使用的器具提袋，其實還可以節省清洗的資源消耗唷^^  100010884549985
# 37                                      還有比塑膠袋好清洗的嗎？😂  100010884549985
# 36                                     為了地球再麻煩小編都願意 💪  100010884549985
# 35                              小編，我住家最近網速有點慢可以協助處理嗎?  360044337354953
# 34  建議您可以透過客服信箱(https://www.tstartel.com/CWS/servi...  100000338194155
# 33                                    大家一起做  真實效益才會顯現  360044337354953
# 32                                             真的 👍👍👍  100014665151778
# 31                                          你去跟市場的阿姨說  360044337354953
# 30                                  噗 ~ 帶環保袋和環保餐具去市場咩        775553146
# 13    若是突然發生~小編建議可以先試試看1⃣將手機背景程式清空2⃣將手機關機約10-15秒再重新開機  100000950539467
# 14            拒絕一次性塑膠袋和一次性餐具，個人麻煩一點點，對地球的幫助不只一點點唷 🌎🌍🌏       1645417439
# 15  一個人做，不如一堆人做，一間企業響應，不如全台灣的企業一起響應，我選擇減碳每天坐交通工具通勤...  360044337354953
# 16  小編相信自己身體力行，多多少少總是能感染到身邊的人的~像是小編會自己帶鍋子或是碗去買三餐呀~...  100000950539467
# 17                             台灣之星 希望台灣每個人都是台灣之星的好寶寶  100000950539467
# 18                          跟著小編一起分享給更多人~~大家都是地球守護者💪💪  100000950539467
# 19                           為什麼現在台灣之星的收訊這麼差 是有什麼原因嗎？  100000950539467
# 20  Wish we can love the earth and ocean and mount...  360044337354953
# 21  不能只是wish，要行動啊 ~~~ 快跟著小編一起環保愛地球，拒絕一次性塑膠袋和一次性餐具 🌍🌍🌍  100034315643583
# 22                                   小編回覆在您的另外一則留言中囉!  100000950539467
# 23                           沒有完整配套和規劃管理，環保只是商人和政客的口號  360044337354953
# 29                            講環保誰都會講 真的沒帶筷子還不是會用免洗的🙄  360044337354953
# 25                                            這些明星我支持  360044337354953
# 26    小編有私訊您嚕~請您幫忙依照小編說明提供相關資訊並於完成後點選【轉接客服小編】通知小編一聲唷~  100008690050912
# 24                                無條件支持愛地球的everybody💪  100000196821133
#
#          RepName                                               Link  \
# 48           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 61           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 70           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 69           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 68           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 67           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 66           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 65           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 64           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 63           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 62           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 60           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 72           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 59           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 58           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 57           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 56           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 55           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 54           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 53           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 52           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 51           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 71           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 73           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 49           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 85  Ching Kit Ho  https://www.facebook.com/tstartel/photos/a.413...
# 94           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 93           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 92           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 91           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# ..           ...                                                ...
# 12          台灣之星  https://www.facebook.com/tstartel/photos/a.413...
# 0            榮宇晏  https://www.facebook.com/tstartel/photos/a.413...
# 28       Wei Lun  https://www.facebook.com/tstartel/posts/328473...
# 27          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 40           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 39          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 38    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 37    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 36    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 35          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 34           周書楷  https://www.facebook.com/tstartel/posts/328473...
# 33          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 32           陳秋蘭  https://www.facebook.com/tstartel/posts/328473...
# 31          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 30    Long Chang  https://www.facebook.com/tstartel/posts/328473...
# 13           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 14           史考特  https://www.facebook.com/tstartel/posts/328473...
# 15          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 16           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 17           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 18           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 19           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 20          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 21           林群智  https://www.facebook.com/tstartel/posts/328473...
# 22           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 23          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 29          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 25          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 26           李梓豪  https://www.facebook.com/tstartel/posts/328473...
# 24            曾翔  https://www.facebook.com/tstartel/posts/328473...
#
#           Updatetime
# 48  2019-05-20 23:47
# 61  2019-05-20 23:47
# 70  2019-05-20 23:47
# 69  2019-05-20 23:47
# 68  2019-05-20 23:47
# 67  2019-05-20 23:47
# 66  2019-05-20 23:47
# 65  2019-05-20 23:47
# 64  2019-05-20 23:47
# 63  2019-05-20 23:47
# 62  2019-05-20 23:47
# 60  2019-05-20 23:47
# 72  2019-05-20 23:47
# 59  2019-05-20 23:47
# 58  2019-05-20 23:47
# 57  2019-05-20 23:47
# 56  2019-05-20 23:47
# 55  2019-05-20 23:47
# 54  2019-05-20 23:47
# 53  2019-05-20 23:47
# 52  2019-05-20 23:47
# 51  2019-05-20 23:47
# 71  2019-05-20 23:47
# 73  2019-05-20 23:47
# 49  2019-05-20 23:47
# 85  2019-05-20 23:47
# 94  2019-05-20 23:47
# 93  2019-05-20 23:47
# 92  2019-05-20 23:47
# 91  2019-05-20 23:47
# ..               ...
# 12  2019-05-20 23:46
# 0   2019-05-20 23:46
# 28  2019-05-20 23:45
# 27  2019-05-20 23:45
# 40  2019-05-20 23:45
# 39  2019-05-20 23:45
# 38  2019-05-20 23:45
# 37  2019-05-20 23:45
# 36  2019-05-20 23:45
# 35  2019-05-20 23:45
# 34  2019-05-20 23:45
# 33  2019-05-20 23:45
# 32  2019-05-20 23:45
# 31  2019-05-20 23:45
# 30  2019-05-20 23:45
# 13  2019-05-20 23:45
# 14  2019-05-20 23:45
# 15  2019-05-20 23:45
# 16  2019-05-20 23:45
# 17  2019-05-20 23:45
# 18  2019-05-20 23:45
# 19  2019-05-20 23:45
# 20  2019-05-20 23:45
# 21  2019-05-20 23:45
# 22  2019-05-20 23:45
# 23  2019-05-20 23:45
# 29  2019-05-20 23:45
# 25  2019-05-20 23:45
# 26  2019-05-20 23:45
# 24  2019-05-20 23:45
#
# [96 rows x 8 columns]

# %% [markdown]
# # 其他

# %%
# 原本想要登入的方式獲取連結，但FB會偵測異常行為，暫時先不登入
# 關閉Chrome的「通知」提醒
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-notifications")

driver = webdriver.Chrome(options=chrome_options)
url = 'https://www.facebook.com/'
driver.get(url)
time.sleep(3)

# 啟動瀏覽器並登入Facebook
username = driver.find_element_by_id('email')
username.send_keys('61034b001@gms.ndhu.edu.tw')
passwd=driver.find_element_by_id('pass')
passwd.send_keys('19920309')
button=driver.find_element_by_id('loginbutton')
button.click()
