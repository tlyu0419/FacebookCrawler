# %% [markdown]
# # Facebook爬蟲

# %% [markdown]
# # 定義函數供後續使用

# %% [markdown]
# 在這裡我們先定義一個函數，希望把網頁中各篇貼文的連結都找出來!
# ulr放我們要爬的Facebook網址，n是稍後要送出幾次滾動網頁到底部的命令，藉以加載更多資料。

# %%
def FindLinks(url, n):
    Links = []
    driver.get(url)
    for i in range(n):
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
    driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    soup = BeautifulSoup(driver.page_source)
    posts = soup.findAll('div', {'class':'clearfix y_c3pyo2ta3'})
    for i in posts:
        Links.append('https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0])
    return Links

# %% [markdown]
# 定義一個展開所有留言的函數，透過while迴圈反覆搜尋與點擊「看更多留言」、「看更多回覆」與「看完整貼文內容」等按鈕。
# 在過程中會出現請我們登入或註冊的彈跳視窗，但我們不確定到底什麼時候會跳出，因此需要在過程中反覆偵測是有出現這個彈窗，若有就點擊「Not Now」

# %%
# 展開url中的所有留言 與 留言的留言
def expand(url):
    driver.get(url)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    try:
        driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        driver.find_element_by_id('expanding_cta_close_button').click() 
    except:
        time.sleep(1)
    # 偵測是否有「更多留言」（第一層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                driver.find_element_by_id('expanding_cta_close_button').click()
            except:
                time.sleep(0.5)            
            try:
                i.click()
            except:
                time.sleep(0.5)   
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                driver.find_element_by_id('expanding_cta_close_button').click()
            except:
                time.sleep(0.5)
            try:
                i.click()
            except:
                time.sleep(0.5)
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
            except:
                time.sleep(0.5)

# %% [markdown]
# 透過逐層搜索的方式，逐步定位我們要找的資訊
# 在這個環節需要反覆透過Chrome的功能比對資料，需要花一些心力進行比對
# 另外在這部分也使用了大量個try-except，原因是許多資料是有內容才會出現。例如並非每天貼人都會收到「哈哈」、「生氣」的心情。

# %%
# 文章內容與互動摘要
def CrawlPost(soup):
    time.sleep(1)
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # po文人資訊區塊
    PosterInfo = userContent.find('div', {'class':'l_c3pyo2v0u i_c3pynyi2f clearfix'})
    # 互動摘要區(讚、留言與分享)
    feedback = soup.find('form', {'class':'commentable_item collapsed_comments'})
    # 名稱
    Name = PosterInfo.find('img').attrs['aria-label']
    # ID
    ID = PosterInfo.find('a', {'class':'_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe'}).attrs['href'].split('/?',2)[0].split('/',-1)[-1]
    # 網址
    Link = driver.current_url
    # 發文時間
    try:
        Time = PosterInfo.find('abbr').attrs['title']
    except:
        Time = PosterInfo.find('div', {'class':'_1atc fsm fwn fcg'}).text
    # 文章內容
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = ""
    # Like
    try:
        Like = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Like = '0' 
    # Love
    try:
        Love = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_LOVE'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Love = '0' 
    # Haha
    try:
        Haha = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Haha = '0' 
    # Wow
    try:
        Wow = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_WOW'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Wow = '0' 
    # Sad
    try:
        Sad = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_SORRY'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Sad = '0' 
    # Angry
    try:
        Angry = feedback.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label'].split(' ',2)[0]
    except:
        Angry = '0'
    # 留言
    try:
        Comments = feedback.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
    except:
        Comments = '0' 
    # 分享
    try:
        Share = feedback.find('span', {'class':'_355t _4vn2'}).text.split(' ',2)[0]
    except:
        Share = '0' 
    Updatetime = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return pd.DataFrame(
        data = [{'Name':Name,
                 'ID':ID,
                 'Link':Link,
                 'Time':Time,
                 'Content':Content,
                 'Like':Like,
                 'Love':Love,
                 'Haha':Haha,
                 'Wow':Wow,
                 'Sad':Sad,
                 'Angry':Angry,
                 'Comments':Comments,
                 'Share':Share,
                 'Updatetime':Updatetime}],
        columns = ['Name', 'ID', 'Time', 'Content', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Comments', 'Share', 'Link', 'Updatetime'])

# %% [markdown]
# 這邊要留意雖然都是粉絲留言，但實際上分成「回應貼文的留言」與「回應留言的留言」。
# 函數中的第一個迴圈是用來抓「回應貼文的留言」，第二個則是抓「回應留言的留言」。讀者可以自行比較一下兩個迴圈中不同的地方。

# %%
# 留言
def CrawlComment(soup):
    time.sleep(1)
    Comments = pd.DataFrame()
    # po文區塊
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 用戶留言區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    # 回應貼文的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_0'}):
        try:
            Content = i.find('span', {'dir':'ltr'}).text
        except:
            Content = 'sticker'
        Comment = pd.DataFrame(data = [{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'Name':i.find('img').attrs['alt'],
                                 'Time':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'Content':Content,
                                 'Link':driver.current_url}],
                        columns = ['ID', 'Name', 'Time', 'Content', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)
    
    # 回應留言的留言
    for i in userContent.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
        try:
            Content = i.find('span', {'dir':'ltr'}).text
        except:
            Content = 'sticker'
        Comment = pd.DataFrame(data = [{'ID':i.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                 'Name':i.find('img').attrs['alt'],
                                 'Time':i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'],
                                 'Content':Content,
                                 'Link':driver.current_url}],
                        columns = ['ID', 'Name', 'Time', 'Content', 'Link'])
        Comments = pd.concat([Comments, Comment], ignore_index=True)
    Comments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    return Comments

# %% [markdown]
# # 組合應用
# 組合以上函數，針對逐一爬取List中的貼文，依據貼文的類型做後續處理
#
# - 新貼文：爬取貼文與留言
# - 舊貼文但有新留言：更新貼文摘要並爬取留言
# - 舊貼文且無新留言：pass
# - 其他：查看情況

# %% [markdown]
# ## 台星

# %%
url = 'https://www.facebook.com/tstartel/'
Links = FindLinks(url = url, n = 15)
# 抓下來所有留言
for i in Links:
    print('Dealing with: ' + i)
    try:
        driver.get(i)
        time.sleep(1)
        soup = BeautifulSoup(driver.page_source)
        # 檢視文章摘要，分成全新文章、舊文章但有新留言、舊文章也無新留言
        nPost = CrawlPost(soup)
        compare = pd.merge(left = nPost.loc[:,['Link', 'Comments']] ,
                           right = Posts.loc[:,['Link', 'Comments']],
                           how = 'inner',
                           on = ['Link'],
                           indicator=True,
                           suffixes=('_n', '_o'))
        # 新貼文直接爬留言
        if len(compare) == 0:
            print('Type: ' + 'New Post')
            expand(i)
            soup = BeautifulSoup(driver.page_source)
            nComments = CrawlComment(soup)
        # 舊文章但有新留言，僅保留新的留言(drop掉已經在資料庫的資料)
        elif compare.Comments_n.values > compare.Comments_o.values:
            # 開始爬留言並將文章摘要匯入
            print('Type: ' + 'Old Post with New Comments')
            expand(i)
            soup = BeautifulSoup(driver.page_source)
            nComments = CrawlComment(soup)
            nComments = pd.merge(left = nComments,
                                 right = Comments,
                                 how = 'left',
                                 on = ['ID', 'Name', 'Content', 'Link'],
                                 suffixes=('', '_o'),
                                 indicator=True)
            nComments = nComments.loc[nComments._merge == 'left_only',:]
            nComments = nComments.drop(['Time_o', 'Updatetime_o', '_merge'], axis=1)
        # 舊文章也無新留言，pass過去
        elif compare.Comments_n.values == compare.Comments_o.values:
            print('Type: ' + 'Old Post with Old Comments')
            nComments = pd.DataFrame()
        # 其他狀況，請釐清問題
        else:
            print('Type: ' + 'Uncertain condiction! Plz Check this website:' + '...')
            nComments = pd.DataFrame()        
        
        # post的資料直接concat在最下面，並duplicate掉，藉以更新互動摘要
        Posts = pd.concat([Posts, nPost], ignore_index=True)
        Posts = Posts.sort_values(by = 'Updatetime', ascending = False)
        Posts = Posts.drop_duplicates(subset ="Link",
                                      keep= 'first',
                                      inplace = False) 
        Comments = pd.concat([Comments, nComments], ignore_index=True, sort=False)
        print('Result: Succed!')
        print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        print('----------------------------------------------------------')
        print('\n')
    except:
        print('Result: Failed!')
        print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        print('----------------------------------------------------------')
        print('\n')
Posts.to_csv('C:/Users/TL_Yu/Desktop/Posts.csv',index = False)
Comments.to_csv('C:/Users/TL_Yu/Desktop/Comments.csv',index = False)
# Out:
# Dealing with: https://www.facebook.com/tstartel/videos/321955001812559/
# Type: New Post
# Result: Succed!
# Time Log: 2019-05-15 22:14:47
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3269351643090860
# Type: Uncertain condiction! Plz Check this website:...
# Result: Succed!
# Time Log: 2019-05-15 22:14:51
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3267141889978502
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:17
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3259789660713725/
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:32
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3264107533615271/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:35
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3261515247207833
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:39
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3259344244091600
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:43
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3259397344086290/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3254254444600580
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3254038111288880
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:54
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3251586194867405
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:15:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3249335421759149/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3246516712041020/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3243531712339520/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:09
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3243588789000479/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:13
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3241649495861075/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3238717112820980/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:20
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3236285659730792/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:16:23
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3234262259933132/
# Type: Old Post with New Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:38
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3234388456587179/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:42
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/356966824846946/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3231419526884072
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3229153237110701/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:53
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3224660157560009
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:17:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3224692507556774/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:00
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3222529091106449/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:04
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3220095821349776/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:08
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3217437468282278/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:12
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3217249391634419/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/383716782215026/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:20
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3214817948544230/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:24
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2393598470666186/3209498659076159/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:28
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3206630172696341
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:32
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3204484132910945/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:35
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3202371059788919/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:39
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3200691366623555/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:43
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3199870890038936/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:46
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3199637973395561
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:50
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3197740693585289/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:53
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3194840400541985
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:18:57
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2482674201758612/3192347447457947/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/1285036481654086/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3188207417871950
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:09
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3188462841179741
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:12
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3188045531221472/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:16
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3187497977942894/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:19
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3185771428115549/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:23
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3183171725042186/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:27
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3180842608608431
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:31
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3179553862070639/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:34
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3178469558845736/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:38
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3178385162187509
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:41
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3176156975743661/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:47
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.2512681442091221/3173678422658183/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:51
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3169485439744148/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:54
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3168948736464485
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:19:58
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/posts/3166649270027765
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:01
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3164522346907124/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:05
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/videos/589662731510587/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:10
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3161535820539110/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:14
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3159082294117796/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:17
# ----------------------------------------------------------
#
#
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/3156987667660592/
# Type: Old Post with Old Comments
# Result: Succed!
# Time Log: 2019-05-15 22:20:21
# ----------------------------------------------------------

# %% [markdown]
# # Crawl2.0

# %%
import pandas as pd
import re, time, requests, datetime, gc
from selenium import webdriver
from bs4 import BeautifulSoup

# %% [markdown]
# # 截取塗鴉墻貼文資訊並比對先前資料
# 如果每次都把所有貼文抓下來，無疑會浪費程式效能，在這裡我將載入先前的資料，並將各篇貼文分成以下三類：
#
# - **新貼文**：截取貼文內容與留言
# - **舊貼文但有新留言**：截取所有留言但只將新留言加入資料庫
# - **舊貼文也無新留言**：不處理
#
# 可想而知，如果設定排程每天執行，大多數資料都會是「舊貼文也無新留言」的類型，加入這個判斷機制將大幅節省系統效能

# %%
# 截取塗鴉墻上貼文的留言數
def GetWall_PostCommentCounts(i):
    try:
        CommentCounts = i.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0
    return CommentCounts

# 截取塗鴉墻上貼文的連結
def GetWall_PostLink(i):
    Link = 'https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0]
    return Link

# 截取塗鴉墻上貼文的發佈時間
def GetWall_PostTime(i):
    try:
        Time = i.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = 'Not Post'
    return Time

def CarwlList(urls, n, Posts):
    CheckList = pd.DataFrame(columns = ['Link','Time','CommentCounts']) 
    for i in urls:
        driver.get(i)
        for i in range(n):
            try:
                driver.find_element_by_css_selector('a.pam.uiBoxLightblue.uiMorePagerPrimary').click() # 加載更多貼文的按鈕
            except:
                time.sleep(2)
            # 這裡會跳出要我們登入的大畫面，找到「稍後再說」的按鈕並點擊
            try:
                driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
            except:
                time.sleep(0.5)
            soup = BeautifulSoup(driver.page_source)
            for i in soup.find_all('div', {'class':'_5pcr userContentWrapper'}):
                CheckList = pd.concat([CheckList, pd.DataFrame(data = [{'Link':GetWall_PostLink(i),
                                                                        'Time':GetWall_PostTime(i),
                                                                        'CommentCounts':GetWall_PostCommentCounts(i)}],
                                                                 columns = ['Link','Time','CommentCounts'])],
                                       ignore_index = True)
    
    CarwlList = pd.merge(left = CheckList,
                         right = Posts.loc[:,['Link','CommentCounts']],
                         how='left',
                         on='Link',
                         suffixes=('_c', '_p'),
                         indicator=True)
    CarwlList = pd.concat([CarwlList.loc[CarwlList._merge == 'left_only', :], # 新貼文
                           CarwlList.loc[CarwlList.CommentCounts_c > CarwlList.CommentCounts_p, :]], # 舊貼文但有新留言
                          ignore_index=True)
    CarwlList = CarwlList.drop_duplicates(subset = 'Link',
                                          keep= 'first',
                                          inplace = False)
    return CarwlList

# %% [markdown]
# # 爬取特定貼文的內容與留言
# ## 展開貼文與留言

# %%
# 點擊不要現在註冊帳號
def clickNotNow():
    try:
        driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    except:
        time.sleep(1)

# 將顯示的留言從系統推薦改成所有留言

def ClosePopup():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()
    time.sleep(0.5)
    clickNotNow()
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    clickNotNow()
    # 留言排序選new才能抓到全部留言，
    
    # driver.find_element_by_xpath('//a[@data-testid="UFI2ViewOptionsSelector/link"]').click()
    # time.sleep(0.5)
    # try:
    #     driver.find_element_by_partial_link_text('Comments shown in chronological order with the oldest comments')
    # except:
    #     try:
    #         driver.find_element_by_partial_link_text('New comments and those with new replies appear')
    #     except:
    #         print('Plz, Checkthe post arragne type!')

# 打開各篇貼文並展開所有留言 與 留言的留言

def PostExpand():
    time.sleep(2)
    # 偵測是否有「更多留言」（第一層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)   
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))>0:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        for i in driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            clickNotNow()
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)
    # 偵測是否有「更多留言的留言」（第二層），若有則點擊
    while len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))>0:
        for i in driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'):
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            try:
                i.click()
                time.sleep(0.5)
            except:
                time.sleep(0.5)

# %% [markdown]
# ## 爬取貼文內容與留言資訊

# %%
# 貼文留言數
def GetPost_PosterName(userContent):
    return userContent.find('img').attrs['aria-label']

# 貼文留言數
def GetPost_PosterID(userContent):
    return userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1]

# 貼文時間
def GetPost_PostTime(userContent):
    try:
        Time = userContent.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = "Error, Please check this post's condiction!" 
    return Time

# 貼文內容
def GetPost_PostContent(userContent):
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = "There's No Text Content!"
    return Content

# 貼文留言數
def GetPost_PostCommentCounts(userContent):
    try:
        CommentCounts = userContent.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0 
    return CommentCounts

# 貼文分享數
def GetPost_PostShareCounts(userContent):
    try:
        ShareCounts = userContent.find('span', {'class':'_355t _4vn2'}).text.split(' ',2)[0]
        if 'K' in ShareCounts:
            ShareCounts = int(float(ShareCounts.split('K')[0])*1000)
        else:
            ShareCounts = int(ShareCounts)
    except:
        ShareCounts = 0
    return ShareCounts

# 貼文按讚心情數
def GetPost_PostLikeCounts(userContent):
    try:
        LikeCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LIKE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LikeCounts:
            LikeCounts = int(float(LikeCounts.split('K')[0])*1000)
        else:
            LikeCounts = int(LikeCounts)
    except:
        LikeCounts = 0
    return LikeCounts

# 貼文愛心心情數
def GetPost_PostLoveCounts(userContent):
    try:
        LoveCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_LOVE'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in LoveCounts:
            LoveCounts = int(float(LoveCounts.split('K')[0])*1000)
        else:
            LoveCounts = int(LoveCounts)
    except:
        LoveCounts = 0
    return LoveCounts

# 貼文哈哈心情數
def GetPost_PostHahaCounts(userContent):
    try:
        HahaCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_HAHA'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in HahaCounts:
            HahaCounts = int(float(HahaCounts.split('K')[0])*1000)
        else:
            HahaCounts = int(HahaCounts)
    except:
        HahaCounts = 0
    return HahaCounts

# 貼文Wow心情數
def GetPost_PostWowCounts(userContent):
    try:
        WowCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_WOW'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in WowCounts:
            WowCounts = int(float(WowCounts.split('K')[0])*1000)
        else:
            WowCounts = int(WowCounts)
    except:
        WowCounts = 0
    return WowCounts

# 貼文Sad心情數
def GetPost_PostSadCounts(userContent):
    try:
        SadCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_SORRY'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in SadCounts:
            SadCounts = int(float(SadCounts.split('K')[0])*1000)
        else:
            SadCounts = int(SadCounts)
    except:
        SadCounts = 0
    return SadCounts

# 貼文Angry心情數
def GetPost_PostAngryCounts(userContent):
    try:
        AngryCounts = userContent.find('span', {'data-testid':'UFI2TopReactions/tooltip_ANGER'}).find('a').attrs['aria-label'].split(' ',2)[0]
        if 'K' in AngryCounts:
            AngryCounts = int(float(AngryCounts.split('K')[0])*1000)
        else:
            AngryCounts = int(AngryCounts)
    except:
        AngryCounts = 0
    return AngryCounts

# 留言時間
def GetPost_CommentTime(element):
    Time = element.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content']
    Time = datetime.datetime.strptime(Time, '%A, %b %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M")
    return Time

# 留言內容
def GetPost_CommentContent(element):
    try:
        Content = element.find('span', {'dir':'ltr'}).text
    except:
        Content = 'img'
    return Content

# 文章內容與互動摘要
def PostInfo(soup):
    # 貼文區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    PostContent = pd.DataFrame(data = [{'Name':GetPost_PosterName(userContent),
                                    'ID':GetPost_PosterID(userContent),
                                    'Time':GetPost_PostTime(userContent),
                                    'Content':GetPost_PostContent(userContent),
                                    'CommentCounts':GetPost_PostCommentCounts(userContent),
                                    'Shares':GetPost_PostShareCounts(userContent),
                                    'Like':GetPost_PostLikeCounts(userContent),
                                    'Love':GetPost_PostLoveCounts(userContent),
                                    'Haha':GetPost_PostHahaCounts(userContent),
                                    'Wow':GetPost_PostWowCounts(userContent),
                                    'Sad':GetPost_PostSadCounts(userContent),
                                    'Angry':GetPost_PostAngryCounts(userContent),
                                    'Updatetime':datetime.datetime.now().strftime("%Y-%m-%d %H:%M"),
                                    'Link':driver.current_url,}],
                            columns = ['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
    return PostContent

def PostComments(soup):  
    PostComments = pd.DataFrame()
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    try:
        for i in userContent.select('ul._7a9a > li'):
            # 先抓留言並放在Comment
            Comment = pd.DataFrame(data=[{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                          'Name':i.find('img').attrs['alt'],
                                          'Time':datetime.datetime.strptime(i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                          'Content':GetPost_CommentContent(i),
                                          'RepID':userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1],
                                          'RepName':userContent.find('img').attrs['aria-label'],
                                          'Link':driver.current_url}],
                                   columns = ['ID', 'Name', 'Time', 'Content','RepID','RepName','Link'])
            PostComments = pd.concat([PostComments, Comment], ignore_index=True)
            # 留言的留言
            for j in i.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
                Comment = pd.DataFrame(data=[{'ID':j.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'Name':j.find('img').attrs['alt'],
                                              'Time':datetime.datetime.strptime(j.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
                                              'Content':GetPost_CommentContent(j),
                                              'RepID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
                                              'RepName':i.find('img').attrs['alt'],
                                              'Link':driver.current_url}],
                                       columns = ['ID', 'Name', 'Time', 'Content','RepID','RepName','Link'])
                PostComments = pd.concat([PostComments, Comment], ignore_index=True)
        PostComments['Updatetime'] = datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
    except:
        print('Crawl Comments Failed!')
    return PostComments

# %% [markdown]
# # 更新貼文與留言資訊
# 將最新抓到的貼文併回Post表格，並以ID與Time作為關鍵(key)值，取最新抓取的資料(Updatetime)

# %%
def UpdateData(DateFrame_o,DateFrame_n):
    DataFrame = pd.concat([DateFrame_o, DateFrame_n], ignore_index=True)
    DataFrame = DataFrame.sort_values(by = 'Updatetime', ascending = False)
    DataFrame = DataFrame.drop_duplicates(subset = ['ID', 'Time', 'Content'],
                                          keep= 'first',
                                          inplace = False)
    return DataFrame

# %% [markdown]
# # 爬資料
# ## 讀取先前資料
# 若在桌面偵測不到檔案，就創造新的dataframe

# %%
try:
    Posts = pd.read_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
try:
    Comments = pd.read_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName','Link', 'Updatetime'])
    
urls = ['https://www.facebook.com/tstartel/',
        'https://www.facebook.com/chtmobile/',
        'https://www.facebook.com/taiwanmobile/',
        'https://www.facebook.com/fareastone/',
        'https://www.facebook.com/Aptg.tw/']

# %% [markdown]
# ## 產出待爬清單

# %%
driver = webdriver.Chrome()
driver.get('https://www.facebook.com/')
# print(driver.get_cookies())
driver.delete_all_cookies()
driver.add_cookie({'domain': '.facebook.com', 'expiry': 1558752322, 'httpOnly': False, 'name': 'locale', 'path': '/', 'secure': True, 'value': 'en_US'})

# %%
CarwlList = CarwlList(urls=urls, n=30, Posts = Posts)
CarwlList
# Out:
#                                                    Link              Time  \
# 0     https://www.facebook.com/tstartel/photos/a.854...  2019-05-22 02:07
# 9     https://www.facebook.com/tstartel/videos/58966...  2019-03-31 21:03
# 12    https://www.facebook.com/tstartel/videos/40234...  2019-03-24 20:30
# 28    https://www.facebook.com/tstartel/videos/42242...  2019-02-21 04:00
# 37    https://www.facebook.com/tstartel/videos/37158...  2019-02-11 04:00
# 58    https://www.facebook.com/tstartel/posts/299305...  2019-01-16 23:23
# 59    https://www.facebook.com/tstartel/posts/299072...  2019-01-15 22:00
# 60    https://www.facebook.com/tstartel/photos/a.413...  2019-01-14 20:19
# 61    https://www.facebook.com/tstartel/photos/a.413...  2019-01-14 01:00
# 62    https://www.facebook.com/tstartel/photos/a.298...  2019-01-13 20:07
# 63    https://www.facebook.com/tstartel/posts/298398...  2019-01-12 21:21
# 75    https://www.facebook.com/tstartel/photos/a.854...  2019-01-12 01:02
# 76    https://www.facebook.com/tstartel/photos/a.413...  2019-01-10 20:58
# 77    https://www.facebook.com/tstartel/posts/297758...  2019-01-09 20:42
# 78    https://www.facebook.com/tstartel/photos/a.854...  2019-01-09 02:51
# 79    https://www.facebook.com/tstartel/photos/a.413...  2019-01-08 01:00
# 80    https://www.facebook.com/tstartel/posts/297084...  2019-01-06 20:00
# 81    https://www.facebook.com/tstartel/posts/296870...  2019-01-05 20:48
# 82    https://www.facebook.com/tstartel/photos/a.854...  2019-01-04 19:54
# 102   https://www.facebook.com/tstartel/posts/296405...  2019-01-03 20:00
# 103   https://www.facebook.com/tstartel/videos/20054...  2019-01-03 02:41
# 104   https://www.facebook.com/tstartel/photos/a.413...  2018-12-31 18:00
# 105   https://www.facebook.com/tstartel/photos/a.413...  2018-12-31 16:00
# 106   https://www.facebook.com/tstartel/photos/a.413...  2018-12-31 04:00
# 107   https://www.facebook.com/tstartel/photos/a.292...  2018-12-31 02:00
# 108   https://www.facebook.com/tstartel/photos/a.295...  2018-12-30 20:00
# 109   https://www.facebook.com/tstartel/photos/a.292...  2018-12-30 01:58
# 137   https://www.facebook.com/tstartel/photos/a.295...  2018-12-29 20:04
# 138   https://www.facebook.com/tstartel/photos/a.292...  2018-12-29 03:03
# 139   https://www.facebook.com/tstartel/photos/a.295...  2018-12-29 01:04
# ...                                                 ...               ...
# 4634  https://www.facebook.com/taiwanmobile/posts/24...  2019-05-17 21:00
# 4635  https://www.facebook.com/taiwanmobile/posts/24...  2019-05-17 17:00
# 4636  https://www.facebook.com/taiwanmobile/photos/a...  2019-05-16 03:00
# 4644  https://www.facebook.com/taiwanmobile/posts/24...  2019-05-15 17:00
# 4645  https://www.facebook.com/taiwanmobile/photos/a...  2019-05-14 21:00
# 4646  https://www.facebook.com/taiwanmobile/photos/a...  2019-05-12 21:00
# 4647  https://www.facebook.com/taiwanmobile/posts/24...  2019-05-10 21:00
# 4670  https://www.facebook.com/taiwanmobile/posts/24...  2019-05-06 23:00
# 4683  https://www.facebook.com/taiwanmobile/photos/a...  2019-05-01 21:01
# 4996  https://www.facebook.com/fareastone/photos/a.1...  2019-05-21 03:30
# 4997  https://www.facebook.com/fareastone/posts/2546...  2019-05-20 20:45
# 4998  https://www.facebook.com/fareastone/posts/2539...  2019-05-20 03:30
# 4999  https://www.facebook.com/fareastone/videos/561...  2019-05-19 20:45
# 5000  https://www.facebook.com/fareastone/posts/2538...  2019-05-18 20:45
# 5006  https://www.facebook.com/fareastone/posts/2538...  2019-05-18 03:30
# 5007  https://www.facebook.com/fareastone/photos/a.1...  2019-05-17 20:50
# 5008  https://www.facebook.com/fareastone/posts/2535...  2019-05-16 20:45
# 5009  https://www.facebook.com/fareastone/photos/a.1...  2019-05-16 03:15
# 5010  https://www.facebook.com/fareastone/photos/a.1...  2019-05-15 03:30
# 5021  https://www.facebook.com/fareastone/videos/348...  2019-05-10 03:30
# 5044  https://www.facebook.com/fareastone/photos/a.1...  2019-05-07 03:30
# 5045  https://www.facebook.com/fareastone/videos/834...  2019-05-06 03:09
# 5111  https://www.facebook.com/fareastone/photos/a.1...  2019-04-12 20:45
# 5350  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-21 04:00
# 5351  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-20 20:15
# 5354  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-17 20:00
# 5355  https://www.facebook.com/Aptg.tw/videos/639447...  2019-05-17 00:00
# 5360  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-14 22:30
# 5361  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-14 20:00
# 5362  https://www.facebook.com/Aptg.tw/photos/a.1653...  2019-05-14 04:00
#
#      CommentCounts_c CommentCounts_p     _merge
# 0                 23             NaN  left_only
# 9                  0             NaN  left_only
# 12                 0             NaN  left_only
# 28                 0             NaN  left_only
# 37                 0             NaN  left_only
# 58                93             NaN  left_only
# 59               258             NaN  left_only
# 60                84             NaN  left_only
# 61                46             NaN  left_only
# 62                47             NaN  left_only
# 63                10             NaN  left_only
# 75               284             NaN  left_only
# 76               134             NaN  left_only
# 77                28             NaN  left_only
# 78               143             NaN  left_only
# 79               216             NaN  left_only
# 80                16             NaN  left_only
# 81                84             NaN  left_only
# 82                28             NaN  left_only
# 102               14             NaN  left_only
# 103             1100             NaN  left_only
# 104              609             NaN  left_only
# 105              441             NaN  left_only
# 106              107             NaN  left_only
# 107               30             NaN  left_only
# 108                4             NaN  left_only
# 109               22             NaN  left_only
# 137                2             NaN  left_only
# 138               24             NaN  left_only
# 139               30             NaN  left_only
# ...              ...             ...        ...
# 4634               4               2       both
# 4635               3               1       both
# 4636               9               8       both
# 4644               2               1       both
# 4645               3               2       both
# 4646             381             380       both
# 4647              14              11       both
# 4670               6               5       both
# 4683               7               6       both
# 4996             330             290       both
# 4997              25              22       both
# 4998              30              27       both
# 4999              20              18       both
# 5000             163             134       both
# 5006              28              25       both
# 5007              25              21       both
# 5008            1300            1200       both
# 5009              28              27       both
# 5010            9700            9600       both
# 5021              34              33       both
# 5044             523             522       both
# 5045             859             855       both
# 5111              13              12       both
# 5350               4               3       both
# 5351             695             565       both
# 5354             538             471       both
# 5355             795             731       both
# 5360            2400            2300       both
# 5361            1000             971       both
# 5362             610             609       both
#
# [478 rows x 5 columns]

# %% [markdown]
# 如同上面的說明，當CheckLists「merge」欄位為「left_only」時表示該貼文是新貼文；
#
# 而當「merge」欄位為「both」，但「Comments_c」的值大於「Comments_p」時，表示該貼文是舊資料但有新留言。
#
# 以下將截取這兩類的貼文作為爬取清單

# %% [markdown]
# ## 執行爬蟲

# %%
for i in CarwlList.Link:
    print('Dealing with: ' + i)
    driver.get(i)
    try:
        ClosePopup()
        PostExpand()
        try:
            soup = BeautifulSoup(driver.page_source)
            nPost = PostInfo(soup)
            nComments = PostComments(soup)
            try:
                Posts = UpdateData(DateFrame_o = Posts, DateFrame_n = nPost)
                Comments = UpdateData(DateFrame_o = Comments,DateFrame_n = nComments)
                print('Update Succed!')
            except:
                print('Update Posts or Comments Failed!')
        except:
            print('Crawl Post or Comments Failed!')
    except:
        print('No, Comments, Plz Check this post!')
    gc.collect()
    print('Time Log: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '\n\n------------------')
# Out:
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/3290336180992406/
# Update Succed!
# Time Log: 2019-05-22 22:25:58
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/589662731510587/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:26:03
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/402346110331390/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:26:08
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/422421851841011/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:26:13
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/371588343427008/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:26:18
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2993053210720706
# Update Succed!
# Time Log: 2019-05-22 22:26:36
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2990727180953309
# Update Succed!
# Time Log: 2019-05-22 22:27:13
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2988296414529719/
# Update Succed!
# Time Log: 2019-05-22 22:27:34
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2986319394727421/
# Update Succed!
# Time Log: 2019-05-22 22:27:49
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2986070258085668/2986069721419055/
# Update Succed!
# Time Log: 2019-05-22 22:28:05
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2983989371627090
# Update Succed!
# Time Log: 2019-05-22 22:28:17
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2982142728478421/
# Update Succed!
# Time Log: 2019-05-22 22:28:49
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2979699528722741/
# Update Succed!
# Time Log: 2019-05-22 22:29:17
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2977583908934303
# Update Succed!
# Time Log: 2019-05-22 22:29:30
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2975900285769332/
# Update Succed!
# Time Log: 2019-05-22 22:29:57
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2973423746016986/
# Update Succed!
# Time Log: 2019-05-22 22:30:29
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2970845752941452
# Update Succed!
# Time Log: 2019-05-22 22:30:41
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2968705796488781
# Update Succed!
# Time Log: 2019-05-22 22:30:57
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2966305480062146/
# Update Succed!
# Time Log: 2019-05-22 22:31:12
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2964057863620241
# Update Succed!
# Time Log: 2019-05-22 22:31:23
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/2005454029574404/
# Update Succed!
# Time Log: 2019-05-22 22:35:53
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2948360065190021/
# Update Succed!
# Time Log: 2019-05-22 22:38:06
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2948180211874673/
# Update Succed!
# Time Log: 2019-05-22 22:38:59
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2955056234520404/
# Update Succed!
# Time Log: 2019-05-22 22:39:27
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2954882631204431/
# Update Succed!
# Time Log: 2019-05-22 22:39:43
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2950334901659204/2954357054590322/
# Update Succed!
# Time Log: 2019-05-22 22:39:51
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2952616248097736/
# Update Succed!
# Time Log: 2019-05-22 22:40:02
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2950334901659204/2952107238148637/
# C:\Users\TL_Yu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Update Succed!
# Time Log: 2019-05-22 22:40:11
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2950483158311045/
# Update Succed!
# Time Log: 2019-05-22 22:40:23
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2950334901659204/2950334934992534/
# Update Succed!
# Time Log: 2019-05-22 22:40:36
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2948397731852921/
# Update Succed!
# Time Log: 2019-05-22 22:40:52
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2947950968564264/
# Update Succed!
# Time Log: 2019-05-22 22:41:05
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2946274815398546/
# Update Succed!
# Time Log: 2019-05-22 22:41:37
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/2262796523964372/
# Update Succed!
# Time Log: 2019-05-22 22:42:38
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2943631298996231
# Update Succed!
# Time Log: 2019-05-22 22:42:59
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2938858052806889/
# Update Succed!
# Time Log: 2019-05-22 22:43:24
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2939582119401149
# Update Succed!
# Time Log: 2019-05-22 22:43:52
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2938854619473899
# Update Succed!
# Time Log: 2019-05-22 22:44:12
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2937091926316835/
# Update Succed!
# Time Log: 2019-05-22 22:44:29
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2934668439892517/
# Update Succed!
# Time Log: 2019-05-22 22:44:48
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2935079023184792/
# Update Succed!
# Time Log: 2019-05-22 22:46:35
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2934677683224926/
# Update Succed!
# Time Log: 2019-05-22 22:48:30
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2932940713398623/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:48:35
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2931175330241828/
# Update Succed!
# Time Log: 2019-05-22 22:48:46
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/547957789013157/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 22:48:53
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.2928670780492283/2928669847159043/
# Update Succed!
# Time Log: 2019-05-22 22:49:21
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2928194383873256
# Update Succed!
# Time Log: 2019-05-22 22:49:36
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2926693560690005/
# Update Succed!
# Time Log: 2019-05-22 22:50:11
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2926067534085941
# Update Succed!
# Time Log: 2019-05-22 22:50:32
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2924206960938665/
# Update Succed!
# Time Log: 2019-05-22 22:52:11
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2922281884464506/
# Update Succed!
# Time Log: 2019-05-22 22:52:26
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2920345154658179
# Update Succed!
# Time Log: 2019-05-22 22:52:42
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2919925554700139/
# Update Succed!
# Time Log: 2019-05-22 22:52:57
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2917864231572938
# Update Succed!
# Time Log: 2019-05-22 22:53:18
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2917571961602165/
# Update Succed!
# Time Log: 2019-05-22 22:53:34
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2915796831779678/
# Update Succed!
# Time Log: 2019-05-22 22:53:48
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2913849701974391/
# Update Succed!
# Time Log: 2019-05-22 22:55:00
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2911959265496768/
# Update Succed!
# Time Log: 2019-05-22 22:55:13
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2909966862362675/
# Update Succed!
# Time Log: 2019-05-22 22:55:32
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/336691920243512/
# Update Succed!
# Time Log: 2019-05-22 22:55:49
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2907403965952298
# Update Succed!
# Time Log: 2019-05-22 22:56:00
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2905264549499573
# Update Succed!
# Time Log: 2019-05-22 22:56:10
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2904782376214457/
# Update Succed!
# Time Log: 2019-05-22 22:56:31
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2902801023079259/
# Update Succed!
# Time Log: 2019-05-22 22:56:41
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2900843149941713
# Update Succed!
# Time Log: 2019-05-22 22:56:51
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2900609443298417
# Update Succed!
# Time Log: 2019-05-22 22:57:04
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2899011543458207
# Update Succed!
# Time Log: 2019-05-22 22:57:21
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2898982810127747/
# Update Succed!
# Time Log: 2019-05-22 22:57:31
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2895187290507299
# Update Succed!
# Time Log: 2019-05-22 22:57:44
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2895144470511581
# Update Succed!
# Time Log: 2019-05-22 22:57:58
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2894472090578819/
# Update Succed!
# Time Log: 2019-05-22 22:58:19
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2894015800624448
# Update Succed!
# Time Log: 2019-05-22 22:59:43
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2892432434116118
# Update Succed!
# Time Log: 2019-05-22 23:00:01
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2890205194338842/
# Update Succed!
# Time Log: 2019-05-22 23:00:16
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/videos/335251480622809/
# Update Succed!
# Time Log: 2019-05-22 23:00:28
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2886414568051238
# Update Succed!
# Time Log: 2019-05-22 23:00:39
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2886380078054687/
# Update Succed!
# Time Log: 2019-05-22 23:00:55
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.854369967922385/2885841508108544/
# Update Succed!
# Time Log: 2019-05-22 23:01:10
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2884084971617531/
# Update Succed!
# Time Log: 2019-05-22 23:01:57
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2883649621661066
# Update Succed!
# Time Log: 2019-05-22 23:02:07
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2882117971814231/
# Update Succed!
# Time Log: 2019-05-22 23:02:52
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/photos/a.413576055335114/2873549049337790/
# Update Succed!
# Time Log: 2019-05-22 23:03:38
#
# ------------------
# Dealing with: https://www.facebook.com/tstartel/posts/2869759303050098
# Update Succed!
# Time Log: 2019-05-22 23:07:11
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2722692867760338/
# Update Succed!
# Time Log: 2019-05-22 23:07:19
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2722896354406656/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:24
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2720795567950068
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:28
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2715269541836004/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:32
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E5%BF%AB%E4%BE%86%E4%B8%80%E8%B5%B7%E4%BA%AB%E7%94%A8hami%E7%93%9C%E5%B8%B6%E4%BE%86%E5%A5%BD%E5%BA%B7%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2741451985881855/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:37
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E6%B8%85%E6%98%8E%E9%80%A3%E5%81%87%E8%8F%AF%E7%B7%A8%E6%94%BE%E5%81%87%E7%A7%98%E7%AC%88%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2725299120830475/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:42
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/hami-%E8%80%81%E5%B8%AB%E7%9A%84%E6%9C%89%E7%8D%8E%E5%BE%B5%E7%AD%94%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2714190525274668/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:47
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2625898320773127/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:52
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E6%A6%AE%E7%8D%B2%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9F%E4%B8%89%E5%86%A0%E7%8E%8B%E5%8F%B0%E4%B8%AD%E6%B0%B8%E7%A6%8F%E5%8F%8A%E9%AB%98%E9%9B%84%E4%BA%94%E7%A6%8F%E9%96%80%E5%B8%82%E9%99%90%E5%AE%9A%E5%8A%A0%E7%A2%BC%E6%8A%BD%E7%8D%8E%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2706220829404971/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:07:56
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2621480854548207
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:01
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2627346870628272/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:06
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2614263715269921/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:12
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E6%A6%AE%E7%8D%B2%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9F%E4%B8%89%E5%86%A0%E7%8E%8B%E5%8F%B0%E5%8C%97%E5%A8%81%E7%A7%80%E9%96%80%E5%B8%82%E9%99%90%E5%AE%9A%E5%8A%A0%E7%A2%BC%E6%8A%BD%E7%8D%8E%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2662848237075564/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:17
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E7%B2%89%E7%B5%B2%E9%99%90%E5%AE%9A%E5%85%83%E5%AE%B5%E6%B4%BB%E5%8B%95-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2656547634372291/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:22
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/558948321256016/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:27
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E7%B2%89%E7%B5%B2%E8%B5%B0%E6%98%A5%E5%A5%BD%E7%A6%AE%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2648382135188841/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:32
#
# ------------------
# Dealing with: https://www.facebook.com/events/318455062144356/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:37
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2532700660092894/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:41
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E8%B7%A8%E5%B9%B4%E8%A6%81%E5%8E%BB%E5%93%AA%E7%9B%B8%E6%8F%AA%E4%B8%8D%E7%84%A1%E5%B1%80/2587998977893824/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:47
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2510333632329597/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:51
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E8%AA%AA%E8%AA%AA%E4%BD%A0%E6%9C%80%E7%84%A1%E6%95%B5%E7%9A%84%E6%96%B0%E5%B9%B4%E9%A1%98%E6%9C%9B/2583247125035676/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:08:57
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E8%81%96%E8%AA%95%E7%AF%80%E8%80%81%E5%85%AC%E5%85%AC%E5%9C%A8%E5%93%AA%E8%A3%A1-%E8%80%B6%E8%AA%95%E5%BF%AB%E6%A8%82%E7%AF%87/2575419232485132/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:02
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%81%96%E8%AA%95%E7%AF%80%E9%99%90%E5%AE%9A%E7%A6%AE%E4%BE%86%E4%BA%86/2565766516783737/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:07
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2489623107733983
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:12
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2465839153445712/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:16
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2453969517966009/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:20
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.402072236489091/2453318611364433/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2422782314418063/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:30
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/276243096631254/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:35
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/rog%E9%99%90%E5%AE%9A%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E7%B2%89%E7%B5%B2%E7%A6%8F%E5%88%A9%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2450686354958421/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:40
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%80%E8%B5%B7%E5%B9%AB%E5%B0%8F%E6%88%B4%E5%8A%A0%E6%B2%B9%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2442055132488210/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:46
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%80%E8%B5%B7%E4%BE%86%E4%B8%96%E7%95%8C%E9%9F%B3%E6%A8%82%E7%AF%80%E6%90%96%E6%93%BA%E5%BF%AB%E6%A8%82%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2438743802819343/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:51
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1i%E6%83%85%E6%95%85%E4%BA%8B_%E9%96%83%E9%96%83%E6%83%B9%E4%BA%BA-i-%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2437264972967226/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:09:56
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1-i-%E6%83%85%E6%95%85%E4%BA%8B%E8%BF%BD%E5%B0%8B%E7%9C%9F%E6%84%9B%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2430066503687073/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:10:01
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2348938681802427
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:10:05
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92%E4%B8%AD%E7%A7%8B%E7%89%B9%E5%88%A5%E8%B4%88%E7%A6%AE%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2421323581228032/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:10:10
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E8%AA%B0%E7%9A%84%E9%9D%92%E6%98%A5%E6%9C%80%E7%84%A1%E6%95%B5%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2415707908456266/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:10:15
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2336588946370734
# Update Succed!
# Time Log: 2019-05-22 23:10:25
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2336718923024403/
# Update Succed!
# Time Log: 2019-05-22 23:10:38
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2329992887030340
# Update Succed!
# Time Log: 2019-05-22 23:11:12
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2330177080345254/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:11:17
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2326828097346819
# Update Succed!
# Time Log: 2019-05-22 23:11:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2328147850548177/
# Update Succed!
# Time Log: 2019-05-22 23:12:17
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2325730924123203/
# Update Succed!
# Time Log: 2019-05-22 23:12:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2319745238055105
# Update Succed!
# Time Log: 2019-05-22 23:12:35
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2318112011551761/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:12:40
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2316629425033353/
# Update Succed!
# Time Log: 2019-05-22 23:13:29
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2316855901677372/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:13:34
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/231742824169074/
# Update Succed!
# Time Log: 2019-05-22 23:14:07
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2306554512707511/
# Update Succed!
# Time Log: 2019-05-22 23:14:22
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/hami-pass%E8%AE%93%E6%88%91%E5%80%91%E9%81%B8%E6%93%87%E5%9B%B0%E9%9B%A3%E4%BA%86%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2376852975675093/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:14:27
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2298513896844906/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:14:31
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2296244433738519
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:14:35
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2294540213908941/
# Update Succed!
# Time Log: 2019-05-22 23:14:46
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2289347787761517
# Update Succed!
# Time Log: 2019-05-22 23:14:54
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2287010864661876
# Update Succed!
# Time Log: 2019-05-22 23:15:04
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2284264344936528/
# Update Succed!
# Time Log: 2019-05-22 23:15:20
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2283373828358913/
# Update Succed!
# Time Log: 2019-05-22 23:15:29
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2273896159306680/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:15:34
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E7%94%A8%E4%B9%85%E4%BA%86%E5%A5%BD%E4%BA%8B%E6%9C%83%E8%87%AA%E7%84%B6%E7%99%BC%E7%94%9F%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2344351382258586/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:15:39
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2272030789493217/
# Update Succed!
# Time Log: 2019-05-22 23:15:53
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2269999009696395/
# Update Succed!
# Time Log: 2019-05-22 23:16:06
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2268309936531969
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:16:10
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E7%B6%B2%E9%80%9Fno1%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2336876293006095/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:16:18
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2259439450752351
# Update Succed!
# Time Log: 2019-05-22 23:16:28
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2259742577388705/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:16:32
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2254326851263611/
# Update Succed!
# Time Log: 2019-05-22 23:16:45
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2245355318827431/
# Update Succed!
# Time Log: 2019-05-22 23:16:54
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2243805258982437/
# Update Succed!
# Time Log: 2019-05-22 23:17:20
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2243499549013008
# Update Succed!
# Time Log: 2019-05-22 23:17:30
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2241684815861148/
# Update Succed!
# Time Log: 2019-05-22 23:18:48
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2233359573360339/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:18:52
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2234466016583028/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:18:57
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2233035990059364/
# Update Succed!
# Time Log: 2019-05-22 23:19:15
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2229563987073231/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:20
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2228266037203026
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:24
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2225876380775325
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:28
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2220944874601809/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:33
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2219348474761449/
# Update Succed!
# Time Log: 2019-05-22 23:19:47
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2212834292079534/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:51
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2211302455566051
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:19:55
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2207331665963130/
# Update Succed!
# Time Log: 2019-05-22 23:20:12
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2200556053307358/
# Update Succed!
# Time Log: 2019-05-22 23:20:23
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2197220723640891
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:28
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2202045546491742
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:32
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2196872520342378/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:37
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2188392807857016
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:41
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2186834001346230
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:45
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2195101130519517
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:49
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2163899406973023
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:53
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2190724124290551/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:20:57
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2190705857625711/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:01
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2190626274300336/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:05
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2190224684340495/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:09
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2190060744356889
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:13
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2188734231156207
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:18
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2188060337890263/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:22
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E9%87%91%E6%9B%B2%E7%89%B9%E6%B4%BE%E5%93%A1%E4%BE%86%E5%88%B0%E9%87%91%E6%9B%B2%E6%BC%94%E5%94%B1%E6%9C%83%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2250577874969271/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:29
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/videos/2184876921541938/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:34
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2176919169004380
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:38
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E9%87%91%E6%9B%B2%E7%89%B9%E6%B4%BE%E5%93%A1%E5%85%B8%E7%A6%AE%E5%89%8D%E5%93%A8%E6%88%B0%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2246787815348277/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:44
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2175465495816414/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:48
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2161568043872826
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:21:53
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2175381269158170/
# Update Succed!
# Time Log: 2019-05-22 23:22:03
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E9%87%91%E6%9B%B2%E7%89%B9%E6%B4%BE%E5%93%A1%E5%8D%B3%E5%B0%87%E7%9B%B4%E6%93%8A%E9%87%91%E6%9B%B2%E7%8F%BE%E5%A0%B4%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2239367666090292/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:22:08
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2174051322624498/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:22:13
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2175101695852794
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:22:18
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2167460329950264
# Update Succed!
# Time Log: 2019-05-22 23:22:50
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2166419653387665/
# Update Succed!
# Time Log: 2019-05-22 23:23:06
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E5%85%8D%E8%B2%BB%E5%8E%BB%E9%87%91%E6%9B%B2%E7%8D%8E%E4%B8%AD%E7%8D%8E%E5%90%8D%E5%96%AE/2230451560315236/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:23:11
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2166216626741301/
# Update Succed!
# Time Log: 2019-05-22 23:23:20
#
# ------------------
# Dealing with: https://www.facebook.com/notes/%E4%B8%AD%E8%8F%AF%E9%9B%BB%E4%BF%A1%E8%A1%8C%E5%8B%95%E5%AD%B8%E5%9C%92/%E5%88%B0%E5%BA%95%E8%A6%81%E9%80%81%E4%BB%80%E9%BA%BC%E5%BE%97%E7%8D%8E%E5%90%8D%E5%96%AE/2226553920705000/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:23:26
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2157808864248744/
# Update Succed!
# Time Log: 2019-05-22 23:25:34
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/photos/a.264830403546609/2156634774366153/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:25:39
#
# ------------------
# Dealing with: https://www.facebook.com/chtmobile/posts/2152326088130355
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:25:44
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2480586782161748/
# Update Succed!
# Time Log: 2019-05-22 23:29:43
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2480578298829263
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:29:48
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2475069592713467/
# Update Succed!
# Time Log: 2019-05-22 23:29:58
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2476110232609403
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:02
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2476091885944571
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:06
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2474400126113747
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:10
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2470316226522137
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:15
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2469601513260275
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:19
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2468450323375394
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:23
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2467853280101765
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:27
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2465654553654971
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:30:31
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2465616290325464
# Update Succed!
# Time Log: 2019-05-22 23:30:39
#
# ------------------
# Dealing with: https://www.facebook.com/business/help/788160621327601/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:34:44
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/videos/358594338068396/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:34:49
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2418962841657476
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:34:53
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2418866421667118
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:34:58
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2418162245070869/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:02
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2418160278404399
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:06
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2418157368404690/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:10
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414348758785551
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:15
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2414332028787224/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:19
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414336878786739
# Update Succed!
# Time Log: 2019-05-22 23:35:30
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414268928793534
# Update Succed!
# Time Log: 2019-05-22 23:35:41
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414342148786212
# Update Succed!
# Time Log: 2019-05-22 23:35:51
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2414218682131892/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:35:56
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414331548787272
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:00
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2414298962123864/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:04
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2414317468788680
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:09
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2414150535472040/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:13
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2413435282210232
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:17
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2413472152206545/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:21
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2412808365606257
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:26
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2412712845615809/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:30
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2411214855765608
# Update Succed!
# Time Log: 2019-05-22 23:36:41
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2411342635752830/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:45
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2410540432499717
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:49
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2411323649088062
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:36:54
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2410535955833498
# Update Succed!
# Time Log: 2019-05-22 23:37:09
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2410469922506768/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:13
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2410369735850120/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:17
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2409539705933123
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:22
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2409678825919211
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:26
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/posts/2408838602669900
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:30
#
# ------------------
# Dealing with: https://www.facebook.com/taiwanmobile/photos/a.1448377238716046/2408790436008050/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:37:34
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2546644158682204/
# Update Succed!
# Time Log: 2019-05-22 23:39:11
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2546853291994624/
# Update Succed!
# Time Log: 2019-05-22 23:39:23
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2500015073345113/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:39:27
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/383352309180995/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:39:31
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2438508292829125/
# Update Succed!
# Time Log: 2019-05-22 23:46:27
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2436246363055318/
# Update Succed!
# Time Log: 2019-05-22 23:47:48
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2438506659495955/
# Update Succed!
# Time Log: 2019-05-22 23:48:38
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2438506249495996
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:48:43
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2436245076388780/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:48:47
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2434561136557174
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:48:52
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2434625489884072/
# Update Succed!
# Time Log: 2019-05-22 23:49:22
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2434623889884232/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:49:27
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2437118099634811
# Update Succed!
# Time Log: 2019-05-22 23:49:42
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2436970276316260/
# Update Succed!
# Time Log: 2019-05-22 23:49:50
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2434623143217640/
# Update Succed!
# Time Log: 2019-05-22 23:49:59
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2434621396551148
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:50:03
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429426727070615/
# Update Succed!
# Time Log: 2019-05-22 23:50:17
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429425907070697/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:50:21
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429424930404128/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:50:26
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2429424293737525
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:50:30
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429083060438315/
# Update Succed!
# Time Log: 2019-05-22 23:50:51
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429081600438461/
# Update Succed!
# Time Log: 2019-05-22 23:51:03
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2427697340576887/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:51:07
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2429039733775981
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:51:11
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2429136387099649/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:51:16
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2425086464171308/
# Update Succed!
# Time Log: 2019-05-22 23:51:26
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/2043999902560403/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:51:30
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2425078300838791/
# Update Succed!
# Time Log: 2019-05-22 23:52:05
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2414255965254358/
# Update Succed!
# Time Log: 2019-05-22 23:52:55
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2425085200838101/
# Update Succed!
# Time Log: 2019-05-22 23:53:03
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2423273924352562
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:08
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/574986643000468/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:12
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413969828616305/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:17
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413957258617562/
# Update Succed!
# Time Log: 2019-05-22 23:53:33
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/1220624368104424/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:40
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2414293025250652
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:44
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/688091054921820/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:53:48
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413951248618163/
# Update Succed!
# Time Log: 2019-05-22 23:54:04
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2413950835284871
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:54:09
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413944978618790/
# Update Succed!
# Time Log: 2019-05-22 23:54:24
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2406250579388230/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:54:28
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413944471952174/
# Update Succed!
# Time Log: 2019-05-22 23:54:43
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2413943218618966/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:54:48
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2404692426210712/
# Update Succed!
# Time Log: 2019-05-22 23:55:54
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2403180533028568
# Update Succed!
# Time Log: 2019-05-22 23:56:05
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2404686602877961/
# Update Succed!
# Time Log: 2019-05-22 23:56:22
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/418186975596910/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:56:26
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2404685842878037
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:56:30
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2404724099540878/
# Update Succed!
# Time Log: 2019-05-22 23:56:56
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2404683472878274/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:01
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2404682802878341/
# Update Succed!
# Time Log: 2019-05-22 23:57:27
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2406389376041017/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:31
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2401379986541956/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:35
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2404372609576027
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:40
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2401559163190705/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:44
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2392295377450417
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:49
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/2360511894179431/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:57:53
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2401380276541927/
# Update Succed!
# Time Log: 2019-05-22 23:58:04
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/404051767021651/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:58:08
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2401236699889618/
# Update Succed!
# Time Log: 2019-05-22 23:58:25
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2396356807044274/
# Update Succed!
# Time Log: 2019-05-22 23:58:39
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2392671194079502
# No, Comments, Plz Check this post!
# Time Log: 2019-05-22 23:58:43
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2392674950745793/
# Update Succed!
# Time Log: 2019-05-23 00:00:28
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2392671664079455/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:00:33
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2392667860746502/
# Update Succed!
# Time Log: 2019-05-23 00:01:19
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2395772103769411/
# Update Succed!
# Time Log: 2019-05-23 00:05:36
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2392665217413433
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:05:41
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2373927372620551
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:05:45
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2392677644078857
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:05:49
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2373945995952022/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:05:54
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2391090854237536/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:08:42
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2372662909413664
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:08:47
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2372663492746939/
# Update Succed!
# Time Log: 2019-05-23 00:10:50
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2372660936080528/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:10:55
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368093316537290/
# Update Succed!
# Time Log: 2019-05-23 00:11:15
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368092703204018/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:11:19
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368092173204071/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:11:24
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368091416537480/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:11:28
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368089439871011/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:11:33
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368089056537716/
# Update Succed!
# Time Log: 2019-05-23 00:12:10
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2368088779871077
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:15
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2368086069871348
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:20
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2371035069576448/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:24
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368084623204826/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:28
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368082849871670/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:32
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368081853205103/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:37
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/videos/2227325987588687/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:41
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2368081143205174/
# Update Succed!
# Time Log: 2019-05-23 00:12:51
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2371034152909873/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:12:56
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2367926423220646/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:13:01
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2368079909871964
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:13:05
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2369343366412285/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:13:09
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360645327282089/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:13:13
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360509840628971/
# Update Succed!
# Time Log: 2019-05-23 00:19:36
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360508990629056/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:19:40
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2358724317474190/
# Update Succed!
# Time Log: 2019-05-23 00:20:09
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360508140629141/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:20:13
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2359025070777448/
# Update Succed!
# Time Log: 2019-05-23 00:20:22
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/posts/2360504227296199
# Update Succed!
# Time Log: 2019-05-23 00:25:24
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2352825638064058/
# Update Succed!
# Time Log: 2019-05-23 00:25:53
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360502553963033/
# No, Comments, Plz Check this post!
# Time Log: 2019-05-23 00:25:57
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360500753963213/
# Update Succed!
# Time Log: 2019-05-23 00:53:59
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2360501360629819/
# Update Succed!
# Time Log: 2019-05-23 00:54:08
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2363402047006417/
# Update Succed!
# Time Log: 2019-05-23 00:54:22
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2357149620964993/
# Update Succed!
# Time Log: 2019-05-23 00:56:13
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2358723637474258/
# Update Succed!
# Time Log: 2019-05-23 00:58:27
#
# ------------------
# Dealing with: https://www.facebook.com/fareastone/photos/a.163720023641308/2358723050807650/
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-10-a98b82eedb0c> in <module>()
#       1 for i in CarwlList.Link:
#       2     print('Dealing with: ' + i)
# ----> 3     driver.get(i)
#       4     try:
#       5         ClosePopup()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# TimeoutException: Message: timeout
#   (Session info: chrome=74.0.3729.157)
#   (Driver info: chromedriver=74.0.3729.6 (255758eccf3d244491b8a1317aa76e1ce10d57e9-refs/branch-heads/3729@{#29}),platform=Windows NT 10.0.17763 x86_64)

# %%
Posts = Posts.reset_index(drop=True)
Posts = Posts.loc[:,['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link']]
Posts
# Out:
#      Name                   ID              Time  \
# 0    遠傳電信      162583067088337  2019-01-24 02:30
# 1    遠傳電信      162583067088337  2019-01-24 20:00
# 2    遠傳電信      162583067088337  2019-01-25 20:00
# 3    遠傳電信      162583067088337  2019-01-25 01:30
# 4    遠傳電信      162583067088337  2019-01-26 02:30
# 5    遠傳電信      162583067088337  2019-01-28 02:15
# 6    遠傳電信      162583067088337  2019-01-27 02:30
# 7    遠傳電信      162583067088337  2019-01-29 02:30
# 8    遠傳電信      162583067088337  2019-01-30 02:30
# 9    遠傳電信      162583067088337  2019-02-02 02:30
# 10   遠傳電信      162583067088337  2019-02-07 02:30
# 11   遠傳電信      162583067088337  2019-02-10 02:30
# 12   遠傳電信      162583067088337  2019-02-11 02:30
# 13   遠傳電信      162583067088337  2019-02-14 19:30
# 14   遠傳電信      162583067088337  2019-02-15 02:30
# 15   遠傳電信      162583067088337  2019-02-16 02:30
# 16   遠傳電信      162583067088337  2019-02-17 02:30
# 17   遠傳電信      162583067088337  2019-02-18 19:50
# 18   遠傳電信      162583067088337  2019-02-17 19:45
# 19   遠傳電信      162583067088337  2019-02-22 02:30
# 20   遠傳電信      162583067088337  2019-02-25 02:30
# 21   遠傳電信      162583067088337  2019-02-25 19:50
# 22   遠傳電信      162583067088337  2019-02-23 02:30
# 23   遠傳電信      162583067088337  2019-02-26 02:30
# 24   遠傳電信      162583067088337  2019-02-28 02:30
# 25   遠傳電信      162583067088337  2019-03-01 02:30
# 26   遠傳電信      162583067088337  2019-02-27 02:30
# 27   遠傳電信      162583067088337  2019-03-05 02:30
# 28   遠傳電信      162583067088337  2019-03-03 02:30
# 29   遠傳電信      162583067088337  2019-03-05 19:45
# ..    ...                  ...               ...
# 750  台灣之星      360044337354953  2019-04-22 20:58
# 751  台灣之星      360044337354953  2019-04-23 02:00
# 752  台灣之星      360044337354953  2019-04-25 02:21
# 753  台灣之星      360044337354953  2019-04-26 00:23
# 754  台灣之星      360044337354953  2019-04-24 02:30
# 755  台灣之星      360044337354953  2019-04-28 21:00
# 756  台灣之星      360044337354953  2019-04-27 21:22
# 757  台灣之星      360044337354953  2019-04-26 21:00
# 758  台灣之星  356966824846946:9:0  2019-04-29 01:52
# 759  台灣之星      360044337354953  2019-04-30 05:05
# 760  台灣之星      360044337354953  2019-04-30 02:06
# 761  台灣之星      360044337354953  2019-05-01 21:25
# 762  台灣之星      360044337354953  2019-05-06 00:43
# 763  台灣之星      360044337354953  2019-05-04 02:00
# 764  台灣之星      360044337354953  2019-05-03 20:37
# 765  台灣之星      360044337354953  2019-05-04 20:57
# 766  台灣之星      360044337354953  2019-05-08 02:00
# 767  台灣之星      360044337354953  2019-05-07 02:00
# 768  台灣之星      360044337354953  2019-05-08 21:00
# 769  台灣之星      360044337354953  2019-05-10 04:56
# 770  台灣之星      360044337354953  2019-05-10 02:28
# 771  台灣之星      360044337354953  2019-05-10 21:00
# 772  台灣之星      360044337354953  2019-05-11 21:00
# 773  台灣之星      360044337354953  2019-05-12 06:20
# 774  台灣之星      360044337354953  2019-05-13 01:38
# 775  台灣之星      360044337354953  2019-05-13 22:17
# 776  台灣之星  321955001812559:9:0  2019-05-14 21:00
# 777  台灣之星      360044337354953  2019-05-17 01:00
# 778  台灣之星      360044337354953  2019-05-18 21:00
# 779  台灣之星      360044337354953  2019-05-17 05:10
#
#                                                Content CommentCounts Shares  \
# 0    ✨2019大家一起求運勢，好運一直來✨ 有很多粉粉跟小編敲碗🍽 想要玩12生肖系列的測驗 於...          2500     15
# 1    【新春e起旅遊踩春趣！ #文末抽電影票】 　 小編不得不說遠傳太貼心啦~ 為了讓遠傳用戶帶著...          2400   1000
# 2    2019歡樂依舊！回饋無上限！ 新的一年🎆遠傳愛你依舊~  #遠傳friDay聯名卡 持續給...             5      1
# 3    發票文又來摟！ 趁著過年前先來試試手氣 對個發票看運勢如何🙏 有中獎的話，記得也要分紅給小編...            16     21
# 4    【挑出你的幸運豬！🎊豬你2019都大吉🎊】 OK! 上次用生肖來測運勢 如果你覺得不準，小編...          9100     26
# 5    九天春假前的最後一週上班啦！ 小編先來拜個早年呀~~  ㊗最可愛的粉絲 #豬事大吉 #豬年發...            55      4
# 6    【冬天限定暖心甜湯，你最喜歡哪一個？】 每到冬天， 吃熱呼呼的薑汁豆花最對味💗 來碗甜湯吧！...           229      4
# 7    當你看到這張圖時 你只要照著以下步驟👇 今年就會壞運出去，好運來，整年發大財！ 1⃣5分鐘內...           161     75
# 8    【穿對顏色，2019一路發！】 想知道今年自己的幸運色是哪一個哩？ 那你絕對不能錯過開運好時...          3000     16
# 9    ⚠過年倒數2天⚠ 準備好與親戚過招了嗎？ 過年最難以招架的就是親戚的關愛😣 還有哪些讓人哭哭...            11      3
# 10   🐷七龍豬大作戰！第四關-豬年好運🐷 　 初三忌口不宜出外拜年🤐 趁著今天好好睡到飽！ 睡好睡...           524     69
# 11   🐷七龍豬大作戰！完結🐷 　 新春年假結束， 我們的七龍豬大作戰也完美落幕了！ 謝謝這幾天粉粉...            52      4
# 12   【什麼⁉ 這真的是一個神組合🙏】 ㊗開工第一天....同事拿著這張圖 幫小編取了新名字， 難...           120      4
# 13   終於星期五啦~~~ 小編最愛friDay了😍 恭喜大家在連假過後努力地撐過了一週🎉 為了鼓勵...             7      1
# 14   小編今天下班路上經過了一間柑仔店 發現了好多兒時的回憶😍 像是牙膏巧克力醬、紅燒魚條、跳跳糖...           176     16
# 15   【你內心有不敢面對的那個他嗎？】 　  在別人前總是很堅強💪 在夜裡卻默默的流淚.... 只...          2700     13
# 16   小編算過如果省下吃甜點、零食的錢 就可以去一趟沖繩旅遊✈ 所以我決定今年禁吃零食🚫 好好省錢...            58      8
# 17   【#網路門市 #獨家 旗艦機優惠！】 想買新手機？ 到處比價不如直接在遠傳網路門市結帳 多款...             9      2
# 18   慶元宵，今天大家都吃湯圓了嗎？ 吃湯圓前先來個猜燈謎🏮 小編出個三題，讓大家小試身手💪 快來...            55      9
# 19   久違的台語日又來啦😍 小編知道有很多人都不太會念台語 趁著今天來個台語日 下面五句台語俗諺，...            80     16
# 20   這幾天忙碌的補上過年連假工作進度 讓小編黑眼圈都跑出來了😵 　 今天趁著中午去買了咖啡☕跟巧...            29      0
# 21   很常在網路看到車主停好車🚗 回來開車時忘了停在哪的趣事😂 但是當你有天真的碰上這荒唐的事情時...            20      4
# 22   不管你是天蠶腳、無影腳 還是臭氣熏天的香港腳👣 每種腳型都能看出你的天性特質！ 想知道你的天...           450      3
# 23   咻的一下，又要放連假啦！ 放假完緊接著就是3月😱 　 3月份對自己有什麼要完成的目標嗎？ 接...           581      8
# 24   台灣的後花園去幾次都不會膩😘 　 小編這次來到了台東的 #泰源幽谷 這裡有一群台灣獼猴🐒在這...            22      5
# 25   🤜夜市美食大直擊🤛 　 小編今天來到了 #景美夜市 要來跟大家分享一間好吃的炭烤🍢 不得不說...            23      1
# 26   大家來找碴！🖐個疑點你找到了嗎？ 　 今天愛喜嗲鹿跟著朋友一起去野餐 用iPhone XR傳...            40      2
# 27   今天小編上班偷偷耍費 用手機跟 #Google個人助理 聊天 正當聊得開心，小編問他會不會繞...            26      4
# 28   上一篇的轉職測驗大家討論的好熱烈👏 小編決定再做一篇 #老闆篇！ 讓你一秒了解老闆的個性👍 ...            64      6
# 29   【#網路門市限定 $499短約 加碼雙重送！】#文末抽獎 $499一年短約吃到飽，搭配 #G...          1000    839
# ..                                                 ...           ...    ...
# 750  #MrX編 不是週末才去看美美的 #海芋季 怎麼突然黑一片變這樣😱 其實這是 #黃斑部病變 ...            24     12
# 751  #加值隨你選 #再升級 #爆送萬元抵用金 #虛寶想買就買 #手遊世界輔你稱王 👑http:/...           132     11
# 752  滴答滴答～什麼！竟然過了三個小時😨 #00C編 明明只是滑個FB啊...... 嘿嘿🤭是不是...            14      4
# 753  我的天啊～#00C編 的Google怎麼壞掉了 怎麼好像 #復仇者聯盟 的場景啊 畫面竟然全...            28      5
# 754  嘿嘿嘿，不要懷疑，就是你想的那個 大家不要太羨慕 #週星星編 有票 小編只是搶在第一天 比大...            65      8
# 755  後天是 #勞動節，雖然賺到一天假 但接著就要繳稅吃土一個月😱😱😱 #憤輕編 懷疑這根本就是安...           515    224
# 756  #週1福利日 #每週一1230 #週週登場 聰明的你不用 #MrX編 週週提醒😬 把網址加入...            90      6
# 757  #憤輕編 眼睛要花了啦 這根本是催眠圖片啊😴哪裡有數字喇🤨 大家都有看到數字嗎？留言告訴小編...           209     18
# 758  #eSIM全新上線 #網路門市也能辦 ➡http://bit.ly/2GzAoW5 📣iPh...           109     13
# 759  明天放一天假，做二休一再做二休二 這樣的工作節奏 #U姐編 覺得很可以 但是想到五月要繳稅💸...           552     21
# 760  走過三十個年頭 日本 #平成 #年號 即將在今天畫下句點 緊接而來的 #令和 時代 又會為日...            60     11
# 761  #送雙人饗食天堂假日下午餐券 小編團們苦思母親節活動還在難產時 #週星星編 開了媽媽第一槍後...           431    351
# 762  Blue Monday 加 Rainy Day 🌧 這個星期一 #憤輕編 不開心 只能說早上...           164      8
# 763  春夏交替之際 高速公路🛣沿途都會看到白靄靄的山頭 形成一片雪白的美景 油桐花落時白雪紛飛更有...            29     12
# 764  天公伯啊～可以不要這樣落井下石嗎😭 這個月要吃土繳稅就算了 連玩遊戲的一點小確幸都要剝奪.....            34      2
# 765  【辦門號不吃虧 Ep.3】 這張照片怎麼賴給爸爸❓ 妹妹可以從美國打賴給我喔⁉️ 自從長輩也...            59      4
# 766  是滴～ #00C編 一現身 就知道有最新科技消息要報給大家啦！ 今天要分享的是最新 #And...            11      5
# 767  再過幾天就是 #母親節 了呢☺ 大家準備好要送給媽媽的禮物了嗎？ #U姐編 雖然還沒晉升阿母...            49      3
# 768  #辦就送 #辦就送 #辦就送‼ 👉http://bit.ly/2YexRrG #週星星編 不...           113     10
# 769  #熱騰騰媽媽金句募集中獎公告出爐 小編團們昨天花了一個晚上討論 選出五則讓大家笑到併軌🤣的留...            30      3
# 770  🔥5/10-5/12🔥 #老客戶限定抽iPhoneXS 👉http://bit.ly/2vR...           135     20
# 771  小時候，妳盯著我跟著跟後  出閣時，妳看著我淚眼婆娑  現在妳老了，眼裡還是只有我  💐媽~...            29      2
# 772  #週1福利日 #每週一1230 #週週登場 有好康不提醒 #憤輕編 會整晚睡不著的 現在就把...            31      1
# 773  #熱騰騰的母親節加映場煙火送到 📣媽媽我愛妳~妳~妳(自帶Echo) 大家今天有沒有跟媽媽說...            54      3
# 774  #週星星編 好久沒和大家玩小測驗了～ 雖然母親節剛過，我們還是來暖心一下 問問大家🙋‍♂🙋‍...           368      5
# 775  最近關於手機作業系統更新的消息 整個如雨後春筍般一直冒出來耶 #00C編 都快來不及採收了🤣...            48     15
# 776  東西只要加個 e 就感覺潮到出水💦 但到底什麼是 #eSIM 啊？ 身為 #iPhoneXS...           139     14
# 777  雖然 #00C編 的戰場不在考場在辦公室🤐 但還是心繫努力準備考試的同學們 還有在背後默默支...            69      0
# 778  好想去日本🇯🇵看繡球花唷 小編們聽 #U姐編 嘟嘟囔囔一週快煩死了 交換個眼色，作戰計劃開始...            55     13
# 779                #憤輕編 得到同事送的彩虹糖 Friday Night 覺得甜蜜蜜❤️            61      1
#
#      Like Love Haha Wow Sad Angry        Updatetime  \
# 0     319    0    1   1   0     0  2019-05-23 00:58
# 1    1100    2    0   0   0     0  2019-05-23 00:56
# 2      70    0    0   2   0     1  2019-05-23 00:54
# 3     104    0    0   0   1     0  2019-05-23 00:54
# 4     680    7    0   0   0     0  2019-05-23 00:53
# 5      64    0    0   0   0     0  2019-05-23 00:25
# 6     111    4    0   2   0     0  2019-05-23 00:25
# 7     129    2    1   0   0     0  2019-05-23 00:20
# 8     229    0    3   1   0     0  2019-05-23 00:19
# 9      61    1    0   0   0     0  2019-05-23 00:12
# 10    308    1    1   0   0     0  2019-05-23 00:12
# 11     72    0    0   0   0     0  2019-05-23 00:11
# 12     67    0    5   1   0     0  2019-05-23 00:10
# 13     30    0    0   1   0     0  2019-05-23 00:05
# 14    131    3    8   0   0     0  2019-05-23 00:01
# 15    236    3    0   0   0     0  2019-05-23 00:00
# 16     87    0    0   0   0     0  2019-05-22 23:58
# 17     71    0    0   0   0     0  2019-05-22 23:58
# 18    102    1    1   0   0     0  2019-05-22 23:58
# 19    115    0    9   3   0     0  2019-05-22 23:57
# 20     62    0    0   1   0     0  2019-05-22 23:56
# 21     62    0    1   0   0     0  2019-05-22 23:56
# 22     87    0    1   0   0     0  2019-05-22 23:56
# 23    149    0    0   0   0     0  2019-05-22 23:55
# 24     87    0    1   0   1     0  2019-05-22 23:54
# 25     91    0    0   0   0     0  2019-05-22 23:54
# 26     59    0    0   0   0     0  2019-05-22 23:54
# 27     61    0    2   0   0     0  2019-05-22 23:53
# 28     57    0    0   0   0     0  2019-05-22 23:53
# 29   1000    0    0   0   2     0  2019-05-22 23:52
# ..    ...  ...  ...  ..  ..   ...               ...
# 750   373    4    0  35   0     0  2019-05-21 02:12
# 751   507    6    0   6   0     0  2019-05-21 02:12
# 752   315    4    0   0   0     2  2019-05-21 02:11
# 753   239    0   17   5   0     0  2019-05-21 02:11
# 754   477    9   15   0   0     0  2019-05-21 02:11
# 755   578    5    7   0   0     0  2019-05-21 02:10
# 756   393    5    0   2   0     0  2019-05-21 02:10
# 757   283    0    2   9   0     0  2019-05-21 02:10
# 758   154    4    0   0   3     0  2019-05-21 02:09
# 759   732    0    0  15   0    10  2019-05-21 02:08
# 760   524   14    0   1   0     0  2019-05-21 02:08
# 761   719    7   33   0   0     0  2019-05-21 02:06
# 762   572   12    3   0   0     0  2019-05-21 02:05
# 763   592   13    0   6   0     0  2019-05-21 02:05
# 764   332    0   13   8   0     0  2019-05-21 02:05
# 765   326    4    0   6   0     0  2019-05-21 02:05
# 766   222    4    0   4   0     0  2019-05-21 02:04
# 767   280    4    0   9   0     0  2019-05-21 02:04
# 768   324    6    0   4   0     0  2019-05-21 02:00
# 769   170    7   16   0   0     0  2019-05-21 02:00
# 770   526   10    0   0   6     0  2019-05-21 02:00
# 771   289    9    0   0   0     1  2019-05-21 01:59
# 772   241    7    0   0   0     2  2019-05-21 01:59
# 773   314   10    0   0   0     2  2019-05-21 01:59
# 774   263    5    8   0   0     0  2019-05-21 01:59
# 775   336    7    0   8   0     0  2019-05-21 01:58
# 776   136    6    0   1   0     0  2019-05-21 01:58
# 777   270    3   18   0   0     0  2019-05-21 01:53
# 778   626    8    2   0   0     0  2019-05-21 01:52
# 779   160    9    0   0   0     3  2019-05-21 01:52
#
#                                                   Link
# 0    https://www.facebook.com/fareastone/photos/a.1...
# 1    https://www.facebook.com/fareastone/photos/a.1...
# 2    https://www.facebook.com/fareastone/photos/a.1...
# 3    https://www.facebook.com/fareastone/photos/a.1...
# 4    https://www.facebook.com/fareastone/photos/a.1...
# 5    https://www.facebook.com/fareastone/photos/a.1...
# 6    https://www.facebook.com/fareastone/photos/a.1...
# 7    https://www.facebook.com/fareastone/photos/a.1...
# 8    https://www.facebook.com/fareastone/photos/a.1...
# 9    https://www.facebook.com/fareastone/photos/a.1...
# 10   https://www.facebook.com/fareastone/photos/a.1...
# 11   https://www.facebook.com/fareastone/photos/a.1...
# 12   https://www.facebook.com/fareastone/photos/a.1...
# 13   https://www.facebook.com/fareastone/photos/a.1...
# 14   https://www.facebook.com/fareastone/photos/a.1...
# 15   https://www.facebook.com/fareastone/photos/a.1...
# 16   https://www.facebook.com/fareastone/photos/a.1...
# 17   https://www.facebook.com/fareastone/photos/a.1...
# 18   https://www.facebook.com/fareastone/photos/a.1...
# 19   https://www.facebook.com/fareastone/photos/a.1...
# 20   https://www.facebook.com/fareastone/photos/a.1...
# 21   https://www.facebook.com/fareastone/posts/2403...
# 22   https://www.facebook.com/fareastone/photos/a.1...
# 23   https://www.facebook.com/fareastone/photos/a.1...
# 24   https://www.facebook.com/fareastone/photos/a.1...
# 25   https://www.facebook.com/fareastone/photos/a.1...
# 26   https://www.facebook.com/fareastone/photos/a.1...
# 27   https://www.facebook.com/fareastone/photos/a.1...
# 28   https://www.facebook.com/fareastone/photos/a.1...
# 29   https://www.facebook.com/fareastone/photos/a.1...
# ..                                                 ...
# 750  https://www.facebook.com/tstartel/photos/a.854...
# 751  https://www.facebook.com/tstartel/photos/a.413...
# 752  https://www.facebook.com/tstartel/photos/a.854...
# 753  https://www.facebook.com/tstartel/photos/a.413...
# 754  https://www.facebook.com/tstartel/photos/a.413...
# 755  https://www.facebook.com/tstartel/posts/323141...
# 756  https://www.facebook.com/tstartel/photos/a.854...
# 757  https://www.facebook.com/tstartel/posts/322466...
# 758  https://www.facebook.com/tstartel/videos/35696...
# 759  https://www.facebook.com/tstartel/photos/a.413...
# 760  https://www.facebook.com/tstartel/photos/a.251...
# 761  https://www.facebook.com/tstartel/photos/a.413...
# 762  https://www.facebook.com/tstartel/photos/a.251...
# 763  https://www.facebook.com/tstartel/photos/a.413...
# 764  https://www.facebook.com/tstartel/photos/a.854...
# 765  https://www.facebook.com/tstartel/photos/a.413...
# 766  https://www.facebook.com/tstartel/posts/325403...
# 767  https://www.facebook.com/tstartel/posts/325158...
# 768  https://www.facebook.com/tstartel/posts/325425...
# 769  https://www.facebook.com/tstartel/posts/325934...
# 770  https://www.facebook.com/tstartel/photos/a.854...
# 771  https://www.facebook.com/tstartel/posts/326151...
# 772  https://www.facebook.com/tstartel/photos/a.413...
# 773  https://www.facebook.com/tstartel/photos/a.413...
# 774  https://www.facebook.com/tstartel/posts/326714...
# 775  https://www.facebook.com/tstartel/posts/326935...
# 776  https://www.facebook.com/tstartel/videos/32195...
# 777  https://www.facebook.com/tstartel/photos/a.413...
# 778  https://www.facebook.com/tstartel/photos/a.413...
# 779  https://www.facebook.com/tstartel/photos/a.854...
#
# [780 rows x 14 columns]

# %%
Comments = Comments.reset_index(drop=True)
Comments = Comments.loc[:,['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName','Link', 'Updatetime']]
Comments
# Out:
#                      ID            Name              Time  \
# 0       100000308774358             黃圓圓  2019-01-24 19:26
# 1       162583067088337            遠傳電信  2019-01-24 21:01
# 2       100000223452737             陳羿廷  2019-01-24 20:39
# 3       100000187495156     Edison Chan  2019-01-25 23:11
# 4             654899918  HahaTina Hsieh  2019-01-24 23:52
# 5            1139242955     Katrina Liu  2019-01-24 23:39
# 6       162583067088337            遠傳電信  2019-01-24 20:44
# 7             654899918  HahaTina Hsieh  2019-01-24 20:43
# 8       162583067088337            遠傳電信  2019-01-24 20:47
# 9       100001125847032             鍾佩珊  2019-01-24 20:47
# 10           1788131164       Jill Chen  2019-01-24 20:52
# 11      162583067088337            遠傳電信  2019-01-24 20:51
# 12           1788131164       Jill Chen  2019-01-24 20:51
# 13      162583067088337            遠傳電信  2019-01-24 20:55
# 14      100000048895234       Ping Ping  2019-01-24 20:55
# 15      100000342558783       Peter Lin  2019-01-24 21:01
# 16      162583067088337            遠傳電信  2019-01-24 22:08
# 17      162583067088337            遠傳電信  2019-01-24 21:16
# 18      100000218570467    Selena Hsieh  2019-01-24 21:16
# 19      162583067088337            遠傳電信  2019-01-24 21:22
# 20      100002751237540             李筱君  2019-01-24 21:22
# 21      162583067088337            遠傳電信  2019-01-24 21:32
# 22      100000707527260             劉建業  2019-01-24 21:32
# 23      162583067088337            遠傳電信  2019-01-24 21:34
# 24      100000300464541             蔡幸宜  2019-01-24 21:34
# 25      100002171479480       Emma Tsai  2019-01-24 21:34
# 26      162583067088337            遠傳電信  2019-01-24 21:42
# 27      100001860443671             陳螞蟻  2019-01-24 21:41
# 28      162583067088337            遠傳電信  2019-01-24 21:53
# 29      162583067088337            遠傳電信  2019-01-24 20:39
# ...                 ...             ...               ...
# 101423  360044337354953            台灣之星  2019-05-19 20:41
# 101424  360044337354953            台灣之星  2019-05-19 21:08
# 101425  360044337354953            台灣之星  2019-05-19 16:44
# 101426  100008036701674             陳國進  2019-05-19 18:38
# 101427  360044337354953            台灣之星  2019-05-19 15:40
# 101428  360044337354953            台灣之星  2019-05-19 15:56
# 101429  360044337354953            台灣之星  2019-05-19 15:19
# 101430  100008036701674             陳國進  2019-05-19 21:03
# 101431  360044337354953            台灣之星  2019-05-19 17:32
# 101432  100035760513977             蔡寶淑  2019-05-20 11:43
# 101433  100000129379951    Ching Kit Ho  2019-05-19 14:11
# 101434  100008036701674             陳國進  2019-05-20 19:44
# 101435  100034315643583             林群智  2019-05-19 13:02
# 101436  100008036701674             陳國進  2019-05-20 17:18
# 101437  360044337354953            台灣之星  2019-05-19 23:58
# 101438  100008036701674             陳國進  2019-05-20 18:18
# 101439  360044337354953            台灣之星  2019-05-20 18:39
# 101440  360044337354953            台灣之星  2019-05-19 18:56
# 101441  100008036701674             陳國進  2019-05-19 16:35
# 101442  100008036701674             陳國進  2019-05-19 20:37
# 101443  360044337354953            台灣之星  2019-05-20 16:48
# 101444  360044337354953            台灣之星  2019-05-19 18:43
# 101445  360044337354953            台灣之星  2019-05-19 22:32
# 101446  360044337354953            台灣之星  2019-05-19 19:40
# 101447  360044337354953            台灣之星  2019-05-19 14:27
# 101448  100029765175441             吳世華  2019-05-19 23:37
# 101449  360044337354953            台灣之星  2019-05-20 17:30
# 101450  360044337354953            台灣之星  2019-05-20 18:01
# 101451  100008036701674             陳國進  2019-05-19 18:51
# 101452  360044337354953            台灣之星  2019-05-19 23:49
#
#                                                   Content            RepID  \
# 0                                                       🐵  162583067088337
# 1                                        好運結果就在私訊中！記得要看噢！  100000342558783
# 2                                                      牛🐮  162583067088337
# 3                               Katrina Liu  Rena Karamət        654899918
# 4                                           Katrina Liu 滾        654899918
# 5                                 HahaTina Hsieh 我是小你兩歲的馬        654899918
# 6                                  不怕不怕！看完今年一定旺！快到私訊收一下吧～        654899918
# 7                                                       龍  162583067088337
# 8                                        好運結果就在私訊中！記得要看噢！  100001125847032
# 9                                                       龍  162583067088337
# 10                                              我的媽啊⋯⋯😭😭😭       1788131164
# 11                                    好運來！一切都順啦！快到私訊看一下吧！       1788131164
# 12                                                     龍🐲  162583067088337
# 13                                       好運結果就在私訊中！記得要看噢！  100000048895234
# 14                                                   兔 ^^  162583067088337
# 15                                                      蛇  162583067088337
# 16                                       好運結果就在私訊中！記得要看噢！  100000290963667
# 17                                    好運來！一切都順啦！快到私訊看一下吧！  100000218570467
# 18                                                      龍  162583067088337
# 19                                     2019運勢！底加啦～快到私訊收一下  100002751237540
# 20                                                      虎  162583067088337
# 21                                    好運來！一切都順啦！快到私訊看一下吧！  100000707527260
# 22                                                      兔  162583067088337
# 23                                     2019運勢！底加啦～快到私訊收一下  100000300464541
# 24                                                      龍  162583067088337
# 25                                                     羊🐑  162583067088337
# 26                                     2019運勢！底加啦～快到私訊收一下  100001860443671
# 27                                                      猴  162583067088337
# 28                                    好運來！一切都順啦！快到私訊看一下吧！  100000019753331
# 29                                 不怕不怕！看完今年一定旺！快到私訊收一下吧～  100000223452737
# ...                                                   ...              ...
# 101423                                             國進到家啦❓  100008036701674
# 101424                       加油加油(๑˃̵ᴗ˂̵)ﻭ其實上課是很幸福D~~晚安😉😉  100008036701674
# 101425                                    就叫你溫泉不要泡太久了吧~😂😂  100008036701674
# 101426                                           台灣之星 😟😟😟  100008036701674
# 101427                                         賞心悅目~心情好❤🌼  100008036701674
# 101428                                               ❤Yes  100008036701674
# 101429  不好意思，因為小編這邊沒有查詢的系統，建議正傑從官網👉訂單查詢👉重啟訂單裡面找找看還是沒有的...  100000129379951
# 101430                                 台灣之星 明天又要上課，小編晚安~~  100008036701674
# 101431                                     每日大笑三聲有益身體健康❤❤  100008036701674
# 101432                                             好漂亮的花海  360044337354953
# 101433              門號收到兩天了 也都開通了 但門號還是都不能使用 都沒有客服可以通電話的嗎  360044337354953
# 101434                                     台灣之星 哇靠，機掰完蛋~~  100008036701674
# 101435                                       Good flowers  360044337354953
# 101436                          台灣之星  還好我16:00回到家過一下才下雨~~  100008036701674
# 101437                                            怎口以這樣說💔  100025965258813
# 101438               台灣之星 哇~今天的大雨~北部有一些學校也有發布停課通知呢~（真的假的）  100008036701674
# 101439                                   對啊~~~那大雨像用倒的一樣😫😫  100008036701674
# 101440                                       這樣才乖 (･ิω･ิ)  100008036701674
# 101441                       台灣之星 好熱好熱好熱好熱好熱好熱好熱好熱好熱熱熱熱~~  100008036701674
# 101442                                  台灣之星 ε٩(๑> ₃ <)7з  100008036701674
# 101443                                         有沒有記得帶雨傘呀~  100008036701674
# 101444                                     這4不願意的臉嗎(ノಠ益ಠ)  100008036701674
# 101445                                              大推~❤❤  100034741457030
# 101446                                                img  100008036701674
# 101447  不好意思造成您的不便了~請正傑幫幫忙，透過客服信箱(https://www.tstartel...  100000129379951
# 101448                                       台灣之星 你不是公仔嗎？  100025965258813
# 101449     國進lucky耶~到家才下雨~完美躲過了~記得要點【轉接客服小編】小編才會收到您的私訊唷!!  100008036701674
# 101450                                   收到國進的私訊嚕~咱們私訊見囉~  100008036701674
# 101451                                         台灣之星 沒啦😆😆😆  100008036701674
# 101452                                         為什麼是公仔'ㅅ'❓  100025965258813
#
#                RepName                                               Link  \
# 0                 遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 1            Peter Lin  https://www.facebook.com/fareastone/photos/a.1...
# 2                 遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 3       HahaTina Hsieh  https://www.facebook.com/fareastone/photos/a.1...
# 4       HahaTina Hsieh  https://www.facebook.com/fareastone/photos/a.1...
# 5       HahaTina Hsieh  https://www.facebook.com/fareastone/photos/a.1...
# 6       HahaTina Hsieh  https://www.facebook.com/fareastone/photos/a.1...
# 7                 遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 8                  鍾佩珊  https://www.facebook.com/fareastone/photos/a.1...
# 9                 遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 10           Jill Chen  https://www.facebook.com/fareastone/photos/a.1...
# 11           Jill Chen  https://www.facebook.com/fareastone/photos/a.1...
# 12                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 13           Ping Ping  https://www.facebook.com/fareastone/photos/a.1...
# 14                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 15                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 16                 盛景俠  https://www.facebook.com/fareastone/photos/a.1...
# 17        Selena Hsieh  https://www.facebook.com/fareastone/photos/a.1...
# 18                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 19                 李筱君  https://www.facebook.com/fareastone/photos/a.1...
# 20                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 21                 劉建業  https://www.facebook.com/fareastone/photos/a.1...
# 22                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 23                 蔡幸宜  https://www.facebook.com/fareastone/photos/a.1...
# 24                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 25                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 26                 陳螞蟻  https://www.facebook.com/fareastone/photos/a.1...
# 27                遠傳電信  https://www.facebook.com/fareastone/photos/a.1...
# 28       Chia Yin Tsai  https://www.facebook.com/fareastone/photos/a.1...
# 29                 陳羿廷  https://www.facebook.com/fareastone/photos/a.1...
# ...                ...                                                ...
# 101423             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101424             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101425             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101426             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101427             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101428             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101429    Ching Kit Ho  https://www.facebook.com/tstartel/photos/a.413...
# 101430             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101431             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101432            台灣之星  https://www.facebook.com/tstartel/photos/a.413...
# 101433            台灣之星  https://www.facebook.com/tstartel/photos/a.413...
# 101434             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101435            台灣之星  https://www.facebook.com/tstartel/photos/a.413...
# 101436             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101437             李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 101438             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101439             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101440             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101441             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101442             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101443             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101444             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101445             吳世凱  https://www.facebook.com/tstartel/photos/a.413...
# 101446             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101447    Ching Kit Ho  https://www.facebook.com/tstartel/photos/a.413...
# 101448             李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 101449             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101450             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101451             陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 101452             李文慈  https://www.facebook.com/tstartel/photos/a.413...
#
#               Updatetime
# 0       2019-05-23 00:58
# 1       2019-05-23 00:58
# 2       2019-05-23 00:58
# 3       2019-05-23 00:58
# 4       2019-05-23 00:58
# 5       2019-05-23 00:58
# 6       2019-05-23 00:58
# 7       2019-05-23 00:58
# 8       2019-05-23 00:58
# 9       2019-05-23 00:58
# 10      2019-05-23 00:58
# 11      2019-05-23 00:58
# 12      2019-05-23 00:58
# 13      2019-05-23 00:58
# 14      2019-05-23 00:58
# 15      2019-05-23 00:58
# 16      2019-05-23 00:58
# 17      2019-05-23 00:58
# 18      2019-05-23 00:58
# 19      2019-05-23 00:58
# 20      2019-05-23 00:58
# 21      2019-05-23 00:58
# 22      2019-05-23 00:58
# 23      2019-05-23 00:58
# 24      2019-05-23 00:58
# 25      2019-05-23 00:58
# 26      2019-05-23 00:58
# 27      2019-05-23 00:58
# 28      2019-05-23 00:58
# 29      2019-05-23 00:58
# ...                  ...
# 101423  2019-05-21 01:52
# 101424  2019-05-21 01:52
# 101425  2019-05-21 01:52
# 101426  2019-05-21 01:52
# 101427  2019-05-21 01:52
# 101428  2019-05-21 01:52
# 101429  2019-05-21 01:52
# 101430  2019-05-21 01:52
# 101431  2019-05-21 01:52
# 101432  2019-05-21 01:52
# 101433  2019-05-21 01:52
# 101434  2019-05-21 01:52
# 101435  2019-05-21 01:52
# 101436  2019-05-21 01:52
# 101437  2019-05-21 01:52
# 101438  2019-05-21 01:52
# 101439  2019-05-21 01:52
# 101440  2019-05-21 01:52
# 101441  2019-05-21 01:52
# 101442  2019-05-21 01:52
# 101443  2019-05-21 01:52
# 101444  2019-05-21 01:52
# 101445  2019-05-21 01:52
# 101446  2019-05-21 01:52
# 101447  2019-05-21 01:52
# 101448  2019-05-21 01:52
# 101449  2019-05-21 01:52
# 101450  2019-05-21 01:52
# 101451  2019-05-21 01:52
# 101452  2019-05-21 01:52
#
# [101453 rows x 8 columns]

# %%
Posts.to_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
Comments.to_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')

# %%
Posts.to_csv('C:/Users/TL_Yu/Desktop/Posts.csv')
Comments.to_csv('C:/Users/TL_Yu/Desktop/Comments.csv')

# %% [markdown]
# # 維護測試區

# %%
try:
    Posts = pd.read_pickle('C:/Users/TL_Yu/Desktop/Posts.plk')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'CommentCounts', 'Shares', 'Like', 'Love', 'Haha', 'Wow', 'Sad', 'Angry', 'Updatetime', 'Link'])
try:
    Comments = pd.read_pickle('C:/Users/TL_Yu/Desktop/Comments.plk')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName','Link', 'Updatetime'])
    
urls = ['https://www.facebook.com/tstartel/',
        'https://www.facebook.com/chtmobile/',
        'https://www.facebook.com/taiwanmobile/',
        'https://www.facebook.com/fareastone/',
        'https://www.facebook.com/Aptg.tw/']

# %%
driver = webdriver.Chrome()
driver.get('https://www.facebook.com/')
# print(driver.get_cookies())
driver.delete_all_cookies()
driver.add_cookie({'domain': '.facebook.com', 'expiry': 1558752322, 'httpOnly': False, 'name': 'locale', 'path': '/', 'secure': True, 'value': 'en_US'})

# %%
https://www.facebook.com/tstartel/photos/a.854369967922385/3277739692252055/
# Out:
# a
# b
# c
# d
# e
# f
# Expand Post Comments Succed!a

# %%
driver.get('https://www.facebook.com/chtmobile/photos/a.264830403546609/2722488054447486/')

# %%
ClosePopup()

# %%
PostExpand()

# %%
soup = BeautifulSoup(driver.page_source)

# %%
nPost = PostInfo(soup)
nPost
# Out:
#        Name               ID              Time  \
# 0  中華電信行動學園  166459533383697  2019-05-17 02:00
#
#                                              Content  CommentCounts  Shares  \
# 0  【1…2…3 Cheese！ 怎麼拍都麻吉】 走到哪拍到哪！紀錄最珍貴的日常 #隨時上傳分享...              1       3
#
#    Like  Love  Haha  Wow  Sad  Angry        Updatetime  \
# 0    32     0     0    0    0      0  2019-05-22 09:32
#
#                                                 Link
# 0  https://www.facebook.com/chtmobile/photos/a.26...

# %%
nComments = PostComments(soup)
nComments
# Out:
# Empty DataFrame
# Columns: [Updatetime]
# Index: []

# %%
Posts = UpdateData(DateFrame_o = Posts, DateFrame_n = nPost)
Posts
# Out:
#    Name               ID              Time  \
# 2  台灣之星  360044337354953  2019-05-18 21:00
# 0  台灣之星  360044337354953  2019-05-19 02:00
# 1  台灣之星  360044337354953  2019-05-19 20:52
#
#                                              Content CommentCounts Shares  \
# 2  好想去日本🇯🇵看繡球花唷 小編們聽 #U姐編 嘟嘟囔囔一週快煩死了 交換個眼色，作戰計劃開始...            55     13
# 0  #週1福利日 #每週一1230 #週週登場 有沒有人跟 #00C編 一樣 手機沒電會狂症發作...            13      4
# 1  反正只要一兩塊錢 買個袋子裝一裝，比較方便啦😆 環保餐具用完還要洗，好麻煩 直接拿竹筷和塑膠...            35     13
#
#   Like Love Haha Wow Sad Angry        Updatetime  \
# 2  626    8    2   0   0     0  2019-05-20 23:47
# 0  299    3    0   5   0     0  2019-05-20 23:46
# 1   79    1    0   0   3     0  2019-05-20 23:45
#
#                                                 Link
# 2  https://www.facebook.com/tstartel/photos/a.413...
# 0  https://www.facebook.com/tstartel/photos/a.413...
# 1  https://www.facebook.com/tstartel/posts/328473...

# %%
Comments = UpdateData(DateFrame_o = Comments,DateFrame_n = nComments)
Comments
# Out:
#                  ID        Name              Time  \
# 48  360044337354953        台灣之星  2019-05-19 15:52
# 61  360044337354953        台灣之星  2019-05-19 19:40
# 70  100008036701674         陳國進  2019-05-20 17:18
# 69  360044337354953        台灣之星  2019-05-20 16:48
# 68  100008036701674         陳國進  2019-05-20 16:44
# 67  360044337354953        台灣之星  2019-05-19 21:08
# 66  100008036701674         陳國進  2019-05-19 21:03
# 65  360044337354953        台灣之星  2019-05-19 20:47
# 64  100008036701674         陳國進  2019-05-19 20:42
# 63  360044337354953        台灣之星  2019-05-19 20:41
# 62  100008036701674         陳國進  2019-05-19 20:37
# 60  100008036701674         陳國進  2019-05-19 19:29
# 72  100008036701674         陳國進  2019-05-20 17:20
# 59  360044337354953        台灣之星  2019-05-19 18:56
# 58  100008036701674         陳國進  2019-05-19 18:51
# 57  360044337354953        台灣之星  2019-05-19 18:43
# 56  100008036701674         陳國進  2019-05-19 18:38
# 55  360044337354953        台灣之星  2019-05-19 17:32
# 54  100008036701674         陳國進  2019-05-19 17:18
# 53  360044337354953        台灣之星  2019-05-19 16:44
# 52  100008036701674         陳國進  2019-05-19 16:35
# 51  360044337354953        台灣之星  2019-05-19 15:56
# 71  100008036701674         陳國進  2019-05-20 17:19
# 73  360044337354953        台灣之星  2019-05-20 17:30
# 49  100008036701674         陳國進  2019-05-19 15:52
# 85  360044337354953        台灣之星  2019-05-19 15:19
# 94  100029765175441         吳世華  2019-05-19 23:51
# 93  360044337354953        台灣之星  2019-05-19 23:49
# 92  100029765175441         吳世華  2019-05-19 23:37
# 91  360044337354953        台灣之星  2019-05-19 23:10
# ..              ...         ...               ...
# 12  100000270862585         榮宇晏  2019-05-19 20:40
# 0   360044337354953        台灣之星  2019-05-19 20:46
# 28  360044337354953        台灣之星  2019-05-20 22:29
# 27  100008690050912         李梓豪  2019-05-20 20:39
# 40  100008690050912         李梓豪  2019-05-20 20:40
# 39  100010884549985  Angus Liao  2019-05-20 13:03
# 38  360044337354953        台灣之星  2019-05-20 13:15
# 37  100010884549985  Angus Liao  2019-05-20 15:43
# 36  360044337354953        台灣之星  2019-05-20 15:50
# 35  100000338194155         周書楷  2019-05-20 20:44
# 34  360044337354953        台灣之星  2019-05-20 20:49
# 33  100014665151778         陳秋蘭  2019-05-20 13:01
# 32  360044337354953        台灣之星  2019-05-20 13:10
# 31        775553146  Long Chang  2019-05-20 12:41
# 30  360044337354953        台灣之星  2019-05-20 12:46
# 13  360044337354953        台灣之星  2019-05-20 20:39
# 14  360044337354953        台灣之星  2019-05-20 12:27
# 15  100000950539467         梁啟發  2019-05-20 17:41
# 16  360044337354953        台灣之星  2019-05-20 17:58
# 17  100000950539467         梁啟發  2019-05-20 17:59
# 18  360044337354953        台灣之星  2019-05-20 18:15
# 19  100008690050912         李梓豪  2019-05-20 20:30
# 20  100034315643583         林群智  2019-05-20 12:14
# 21  360044337354953        台灣之星  2019-05-20 12:18
# 22  360044337354953        台灣之星  2019-05-20 20:48
# 23       1645417439         史考特  2019-05-20 12:22
# 29  100000401712214     Wei Lun  2019-05-20 22:16
# 25  100000196821133          曾翔  2019-05-20 12:17
# 26  360044337354953        台灣之星  2019-05-20 20:47
# 24  360044337354953        台灣之星  2019-05-20 12:25
#
#                                               Content            RepID  \
# 48                                     看美美照片一樣心情會hen好  100008036701674
# 61                                                img  100008036701674
# 70                          台灣之星  還好我16:00回到家過一下才下雨~~  100008036701674
# 69                                         有沒有記得帶雨傘呀~  100008036701674
# 68                                       台灣之星 小編，下大雨了  100008036701674
# 67                       加油加油(๑˃̵ᴗ˂̵)ﻭ其實上課是很幸福D~~晚安😉😉  100008036701674
# 66                                 台灣之星 明天又要上課，小編晚安~~  100008036701674
# 65                               早點洗洗睡明天又是新的一天~(✿◠‿◠)  100008036701674
# 64                                           台灣之星 是啊～  100008036701674
# 63                                             國進到家啦❓  100008036701674
# 62                                  台灣之星 ε٩(๑> ₃ <)7з  100008036701674
# 60                                       台灣之星 (〃'▽'〃)  100008036701674
# 72               台灣之星 這肯定會下到淹水~~小編，我傳照片給你（Messenger收）  100008036701674
# 59                                       這樣才乖 (･ิω･ิ)  100008036701674
# 58                                         台灣之星 沒啦😆😆😆  100008036701674
# 57                                     這4不願意的臉嗎(ノಠ益ಠ)  100008036701674
# 56                                           台灣之星 😟😟😟  100008036701674
# 55                                     每日大笑三聲有益身體健康❤❤  100008036701674
# 54                                             台灣之星 笑  100008036701674
# 53                                    就叫你溫泉不要泡太久了吧~😂😂  100008036701674
# 52                       台灣之星 好熱好熱好熱好熱好熱好熱好熱好熱好熱熱熱熱~~  100008036701674
# 51                                               ❤Yes  100008036701674
# 71                            台灣之星  我家的貓兒也在躲雨了，狗兒也是😆😆  100008036701674
# 73     國進lucky耶~到家才下雨~完美躲過了~記得要點【轉接客服小編】小編才會收到您的私訊唷!!  100008036701674
# 49                                        台灣之星 是啊～給大心  100008036701674
# 85  不好意思，因為小編這邊沒有查詢的系統，建議正傑從官網👉訂單查詢👉重啟訂單裡面找找看還是沒有的...  100000129379951
# 94                            台灣之星 意思不是男的嗎難道﹏……＿是偽娘嗎？  100025965258813
# 93                                         為什麼是公仔'ㅅ'❓  100025965258813
# 92                                       台灣之星 你不是公仔嗎？  100025965258813
# 91                           美女是在叫小編嗎❤❤大美女晚安(๑˃̵ᴗ˂̵)ﻭ  100025965258813
# ..                                                ...              ...
# 12                                           舊用戶可以買嗎？  360044337354953
# 0                                      老客戶也可以唷(๑´ڡ`๑)  100000270862585
# 28                                        大家一起動起來~~😊😊  100000401712214
# 27               現在是收訊跟網路有異常嗎？ 為什麼我的收訊只有一格...平常都不會這樣啊  360044337354953
# 40                                     一樣收訊跟網路都變的很慢⋯⋯  100000950539467
# 39  可是我前幾天在清洗用過的（沾到油）塑膠袋時，用掉的水和清潔劑讓我對人生產生問號。@@竹筷我覺...  360044337354953
# 38                 選擇好清洗且可重複使用的器具提袋，其實還可以節省清洗的資源消耗唷^^  100010884549985
# 37                                      還有比塑膠袋好清洗的嗎？😂  100010884549985
# 36                                     為了地球再麻煩小編都願意 💪  100010884549985
# 35                              小編，我住家最近網速有點慢可以協助處理嗎?  360044337354953
# 34  建議您可以透過客服信箱(https://www.tstartel.com/CWS/servi...  100000338194155
# 33                                    大家一起做  真實效益才會顯現  360044337354953
# 32                                             真的 👍👍👍  100014665151778
# 31                                          你去跟市場的阿姨說  360044337354953
# 30                                  噗 ~ 帶環保袋和環保餐具去市場咩        775553146
# 13    若是突然發生~小編建議可以先試試看1⃣將手機背景程式清空2⃣將手機關機約10-15秒再重新開機  100000950539467
# 14            拒絕一次性塑膠袋和一次性餐具，個人麻煩一點點，對地球的幫助不只一點點唷 🌎🌍🌏       1645417439
# 15  一個人做，不如一堆人做，一間企業響應，不如全台灣的企業一起響應，我選擇減碳每天坐交通工具通勤...  360044337354953
# 16  小編相信自己身體力行，多多少少總是能感染到身邊的人的~像是小編會自己帶鍋子或是碗去買三餐呀~...  100000950539467
# 17                             台灣之星 希望台灣每個人都是台灣之星的好寶寶  100000950539467
# 18                          跟著小編一起分享給更多人~~大家都是地球守護者💪💪  100000950539467
# 19                           為什麼現在台灣之星的收訊這麼差 是有什麼原因嗎？  100000950539467
# 20  Wish we can love the earth and ocean and mount...  360044337354953
# 21  不能只是wish，要行動啊 ~~~ 快跟著小編一起環保愛地球，拒絕一次性塑膠袋和一次性餐具 🌍🌍🌍  100034315643583
# 22                                   小編回覆在您的另外一則留言中囉!  100000950539467
# 23                           沒有完整配套和規劃管理，環保只是商人和政客的口號  360044337354953
# 29                            講環保誰都會講 真的沒帶筷子還不是會用免洗的🙄  360044337354953
# 25                                            這些明星我支持  360044337354953
# 26    小編有私訊您嚕~請您幫忙依照小編說明提供相關資訊並於完成後點選【轉接客服小編】通知小編一聲唷~  100008690050912
# 24                                無條件支持愛地球的everybody💪  100000196821133
#
#          RepName                                               Link  \
# 48           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 61           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 70           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 69           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 68           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 67           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 66           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 65           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 64           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 63           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 62           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 60           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 72           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 59           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 58           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 57           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 56           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 55           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 54           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 53           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 52           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 51           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 71           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 73           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 49           陳國進  https://www.facebook.com/tstartel/photos/a.413...
# 85  Ching Kit Ho  https://www.facebook.com/tstartel/photos/a.413...
# 94           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 93           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 92           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# 91           李文慈  https://www.facebook.com/tstartel/photos/a.413...
# ..           ...                                                ...
# 12          台灣之星  https://www.facebook.com/tstartel/photos/a.413...
# 0            榮宇晏  https://www.facebook.com/tstartel/photos/a.413...
# 28       Wei Lun  https://www.facebook.com/tstartel/posts/328473...
# 27          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 40           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 39          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 38    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 37    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 36    Angus Liao  https://www.facebook.com/tstartel/posts/328473...
# 35          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 34           周書楷  https://www.facebook.com/tstartel/posts/328473...
# 33          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 32           陳秋蘭  https://www.facebook.com/tstartel/posts/328473...
# 31          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 30    Long Chang  https://www.facebook.com/tstartel/posts/328473...
# 13           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 14           史考特  https://www.facebook.com/tstartel/posts/328473...
# 15          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 16           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 17           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 18           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 19           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 20          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 21           林群智  https://www.facebook.com/tstartel/posts/328473...
# 22           梁啟發  https://www.facebook.com/tstartel/posts/328473...
# 23          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 29          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 25          台灣之星  https://www.facebook.com/tstartel/posts/328473...
# 26           李梓豪  https://www.facebook.com/tstartel/posts/328473...
# 24            曾翔  https://www.facebook.com/tstartel/posts/328473...
#
#           Updatetime
# 48  2019-05-20 23:47
# 61  2019-05-20 23:47
# 70  2019-05-20 23:47
# 69  2019-05-20 23:47
# 68  2019-05-20 23:47
# 67  2019-05-20 23:47
# 66  2019-05-20 23:47
# 65  2019-05-20 23:47
# 64  2019-05-20 23:47
# 63  2019-05-20 23:47
# 62  2019-05-20 23:47
# 60  2019-05-20 23:47
# 72  2019-05-20 23:47
# 59  2019-05-20 23:47
# 58  2019-05-20 23:47
# 57  2019-05-20 23:47
# 56  2019-05-20 23:47
# 55  2019-05-20 23:47
# 54  2019-05-20 23:47
# 53  2019-05-20 23:47
# 52  2019-05-20 23:47
# 51  2019-05-20 23:47
# 71  2019-05-20 23:47
# 73  2019-05-20 23:47
# 49  2019-05-20 23:47
# 85  2019-05-20 23:47
# 94  2019-05-20 23:47
# 93  2019-05-20 23:47
# 92  2019-05-20 23:47
# 91  2019-05-20 23:47
# ..               ...
# 12  2019-05-20 23:46
# 0   2019-05-20 23:46
# 28  2019-05-20 23:45
# 27  2019-05-20 23:45
# 40  2019-05-20 23:45
# 39  2019-05-20 23:45
# 38  2019-05-20 23:45
# 37  2019-05-20 23:45
# 36  2019-05-20 23:45
# 35  2019-05-20 23:45
# 34  2019-05-20 23:45
# 33  2019-05-20 23:45
# 32  2019-05-20 23:45
# 31  2019-05-20 23:45
# 30  2019-05-20 23:45
# 13  2019-05-20 23:45
# 14  2019-05-20 23:45
# 15  2019-05-20 23:45
# 16  2019-05-20 23:45
# 17  2019-05-20 23:45
# 18  2019-05-20 23:45
# 19  2019-05-20 23:45
# 20  2019-05-20 23:45
# 21  2019-05-20 23:45
# 22  2019-05-20 23:45
# 23  2019-05-20 23:45
# 29  2019-05-20 23:45
# 25  2019-05-20 23:45
# 26  2019-05-20 23:45
# 24  2019-05-20 23:45
#
# [96 rows x 8 columns]

# %% [markdown]
# # 其他

# %%
# 原本想要登入的方式獲取連結，但FB會偵測異常行為，暫時先不登入
# 關閉Chrome的「通知」提醒
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--disable-notifications")

driver = webdriver.Chrome(options=chrome_options)
url = 'https://www.facebook.com/'
driver.get(url)
time.sleep(3)

# 啟動瀏覽器並登入Facebook
username = driver.find_element_by_id('email')
username.send_keys('61034b001@gms.ndhu.edu.tw')
passwd=driver.find_element_by_id('pass')
passwd.send_keys('19920309')
button=driver.find_element_by_id('loginbutton')
button.click()
